# %%
import numpy as np
from sklearn.preprocessing import normalize

def pagerank(x, df=0.85, max_iter=30, bias=None):
    
    """
    Arguments
    ---------
    x : scipy.sparse.csr_matrix
        shape = (n vertex, n vertex)
    df : float
        Damping factor, 0 < df < 1
    max_iter : int
        Maximum number of iteration
    bias : numpy.ndarray or None
        If None, equal bias

    Returns
    -------
    R : numpy.ndarray
        PageRank vector. shape = (n vertex, 1)
    """

    assert 0 < df < 1

    # initialize
    A = normalize(x, axis=0, norm='l1')
    R = np.ones(A.shape[0]).reshape(-1,1)

    # check bias
    if bias is None:
        bias = (1 - df) * np.ones(A.shape[0]).reshape(-1,1)
    else:
        bias = bias.reshape(-1,1)
        bias = A.shape[0] * bias / bias.sum()
        assert bias.shape[0] == A.shape[0]
        bias = (1 - df) * bias

    # iteration
    for _ in range(max_iter):
        R = df * (A * R) + bias

    return R

# %%
from konlpy.tag import Komoran

komoran = Komoran()
def komoran_tokenizer(sent):
    words = komoran.pos(sent, join=True)
    words = [w for w in words if ('/NN' in w or '/XR' in w or '/VA' in w or '/VV' in w)]
    return words

# %%
from collections import Counter
from scipy.sparse import csr_matrix
import numpy as np


def scan_vocabulary(sents, tokenize=None, min_count=2):
    """
    Arguments
    ---------
    sents : list of str
        Sentence list
    tokenize : callable
        tokenize(str) returns list of str
    min_count : int
        Minumum term frequency

    Returns
    -------
    idx_to_vocab : list of str
        Vocabulary list
    vocab_to_idx : dict
        Vocabulary to index mapper.
    """
    counter = Counter(w for sent in sents for w in tokenize(sent))
    counter = {w:c for w,c in counter.items() if c >= min_count}
    idx_to_vocab = [w for w, _ in sorted(counter.items(), key=lambda x:-x[1])]
    vocab_to_idx = {vocab:idx for idx, vocab in enumerate(idx_to_vocab)}
    return idx_to_vocab, vocab_to_idx

def tokenize_sents(sents, tokenize):
    """
    Arguments
    ---------
    sents : list of str
        Sentence list
    tokenize : callable
        tokenize(sent) returns list of str (word sequence)

    Returns
    -------
    tokenized sentence list : list of list of str
    """
    return [tokenize(sent) for sent in sents]

def vectorize(tokens, vocab_to_idx):
    """
    Arguments
    ---------
    tokens : list of list of str
        Tokenzed sentence list
    vocab_to_idx : dict
        Vocabulary to index mapper

    Returns
    -------
    sentence bow : scipy.sparse.csr_matrix
        shape = (n_sents, n_terms)
    """
    rows, cols, data = [], [], []
    for i, tokens_i in enumerate(tokens):
        for t, c in Counter(tokens_i).items():
            j = vocab_to_idx.get(t, -1)
            if j == -1:
                continue
            rows.append(i)
            cols.append(j)
            data.append(c)
    n_sents = len(tokens)
    n_terms = len(vocab_to_idx)
    x = csr_matrix((data, (rows, cols)), shape=(n_sents, n_terms))
    return x

# %%
from collections import defaultdict
from scipy.sparse import csr_matrix

def word_graph(sents, tokenize=None, min_count=2, window=2,
    min_cooccurrence=2, vocab_to_idx=None, verbose=False):
    """
    Arguments
    ---------
    sents : list of str
        Sentence list
    tokenize : callable
        tokenize(str) returns list of str
    min_count : int
        Minumum term frequency
    window : int
        Co-occurrence window size
    min_cooccurrence : int
        Minimum cooccurrence frequency
    vocab_to_idx : dict
        Vocabulary to index mapper.
        If None, this function scan vocabulary first.
    verbose : Boolean
        If True, verbose mode on

    Returns
    -------
    co-occurrence word graph : scipy.sparse.csr_matrix
    idx_to_vocab : list of str
        Word list corresponding row and column
    """
    if vocab_to_idx is None:
        idx_to_vocab, vocab_to_idx = scan_vocabulary(sents, tokenize, min_count)
    else:
        idx_to_vocab = [vocab for vocab, _ in sorted(vocab_to_idx.items(), key=lambda x:x[1])]

    tokens = tokenize_sents(sents, tokenize)
    g = cooccurrence(tokens, vocab_to_idx, window, min_cooccurrence, verbose)
    return g, idx_to_vocab

def cooccurrence(tokens, vocab_to_idx, window=2, min_cooccurrence=2, verbose=False):
    """
    Arguments
    ---------
    tokens : list of list of str
        Tokenized sentence list
    vocab_to_idx : dict
        Vocabulary to index mapper
    window : int
        Co-occurrence window size
    min_cooccurrence : int
        Minimum cooccurrence frequency
    verbose : Boolean
        If True, verbose mode on

    Returns
    -------
    co-occurrence matrix : scipy.sparse.csr_matrix
        shape = (n_vocabs, n_vocabs)
    """
    counter = defaultdict(int)
    for s, tokens_i in enumerate(tokens):
        if verbose and s % 1000 == 0:
            print('\rword cooccurrence counting {}'.format(s), end='')
        vocabs = [vocab_to_idx[w] for w in tokens_i if w in vocab_to_idx]
        n = len(vocabs)
        for i, v in enumerate(vocabs):
            if window <= 0:
                b, e = 0, n
            else:
                b = max(0, i - window)
                e = min(i + window, n)
            for j in range(b, e):
                if i == j:
                    continue
                counter[(v, vocabs[j])] += 1
                counter[(vocabs[j], v)] += 1
    counter = {k:v for k,v in counter.items() if v >= min_cooccurrence}
    n_vocabs = len(vocab_to_idx)
    if verbose:
        print('\rword cooccurrence counting from {} sents was done'.format(s+1))
    return dict_to_mat(counter, n_vocabs, n_vocabs)

def dict_to_mat(d, n_rows, n_cols):
    """
    Arguments
    ---------
    d : dict
        key : (i,j) tuple
        value : float value

    Returns
    -------
    scipy.sparse.csr_matrix
    """
    rows, cols, data = [], [], []
    for (i, j), v in d.items():
        rows.append(i)
        cols.append(j)
        data.append(v)
    return csr_matrix((data, (rows, cols)), shape=(n_rows, n_cols))

# %%
from collections import Counter
import math
import numpy as np
import scipy as sp
from scipy.sparse import csr_matrix
from sklearn.metrics import pairwise_distances


def sent_graph(sents, tokenize=None, min_count=2, min_sim=0.3,
    similarity=None, vocab_to_idx=None, verbose=False):
    """
    Arguments
    ---------
    sents : list of str
        Sentence list
    tokenize : callable
        tokenize(sent) return list of str
    min_count : int
        Minimum term frequency
    min_sim : float
        Minimum similarity between sentences
    similarity : callable or str
        similarity(s1, s2) returns float
        s1 and s2 are list of str.
        available similarity = [callable, 'cosine', 'textrank']
    vocab_to_idx : dict
        Vocabulary to index mapper.
        If None, this function scan vocabulary first.
    verbose : Boolean
        If True, verbose mode on

    Returns
    -------
    sentence similarity graph : scipy.sparse.csr_matrix
        shape = (n sents, n sents)
    """

    if vocab_to_idx is None:
        idx_to_vocab, vocab_to_idx = scan_vocabulary(sents, tokenize, min_count)
    else:
        idx_to_vocab = [vocab for vocab, _ in sorted(vocab_to_idx.items(), key=lambda x:x[1])]

    x = vectorize_sents(sents, tokenize, vocab_to_idx)
    if similarity == 'cosine':
        x = numpy_cosine_similarity_matrix(x, min_sim, verbose, batch_size=1000)
    else:
        x = numpy_textrank_similarity_matrix(x, min_sim, verbose, batch_size=1000)
    return x

def vectorize_sents(sents, tokenize, vocab_to_idx):
    rows, cols, data = [], [], []
    for i, sent in enumerate(sents):
        counter = Counter(tokenize(sent))
        for token, count in counter.items():
            j = vocab_to_idx.get(token, -1)
            if j == -1:
                continue
            rows.append(i)
            cols.append(j)
            data.append(count)
    n_rows = len(sents)
    n_cols = len(vocab_to_idx)
    return csr_matrix((data, (rows, cols)), shape=(n_rows, n_cols))

def numpy_cosine_similarity_matrix(x, min_sim=0.3, verbose=True, batch_size=1000):
    n_rows = x.shape[0]
    mat = []
    for bidx in range(math.ceil(n_rows / batch_size)):
        b = int(bidx * batch_size)
        e = min(n_rows, int((bidx+1) * batch_size))
        psim = 1 - pairwise_distances(x[b:e], x, metric='cosine')
        rows, cols = np.where(psim >= min_sim)
        data = psim[rows, cols]
        mat.append(csr_matrix((data, (rows, cols)), shape=(e-b, n_rows)))
        if verbose:
            print('\rcalculating cosine sentence similarity {} / {}'.format(b, n_rows), end='')
    mat = sp.sparse.vstack(mat)
    if verbose:
        print('\rcalculating cosine sentence similarity was done with {} sents'.format(n_rows))
    return mat

def numpy_textrank_similarity_matrix(x, min_sim=0.3, verbose=True, min_length=1, batch_size=1000):
    n_rows, n_cols = x.shape

    # Boolean matrix
    rows, cols = x.nonzero()
    data = np.ones(rows.shape[0])
    z = csr_matrix((data, (rows, cols)), shape=(n_rows, n_cols))

    # Inverse sentence length
    size = np.asarray(x.sum(axis=1)).reshape(-1)
    size[np.where(size <= min_length)] = 10000
    size = np.log(size)

    mat = []
    for bidx in range(math.ceil(n_rows / batch_size)):

        # slicing
        b = int(bidx * batch_size)
        e = min(n_rows, int((bidx+1) * batch_size))

        # dot product
        inner = z[b:e,:] * z.transpose()

        # sentence len[i,j] = size[i] + size[j]
        norm = size[b:e].reshape(-1,1) + size.reshape(1,-1)
        norm = norm ** (-1)
        norm[np.where(norm == np.inf)] = 0

        # normalize
        sim = inner.multiply(norm).tocsr()
        rows, cols = (sim >= min_sim).nonzero()
        data = np.asarray(sim[rows, cols]).reshape(-1)

        # append
        mat.append(csr_matrix((data, (rows, cols)), shape=(e-b, n_rows)))

        if verbose:
            print('\rcalculating textrank sentence similarity {} / {}'.format(b, n_rows), end='')

    mat = sp.sparse.vstack(mat)
    if verbose:
        print('\rcalculating textrank sentence similarity was done with {} sents'.format(n_rows))

    return mat

def graph_with_python_sim(tokens, verbose, similarity, min_sim):
    if similarity == 'cosine':
        similarity = cosine_sent_sim
    elif callable(similarity):
        similarity = similarity
    else:
        similarity = textrank_sent_sim

    rows, cols, data = [], [], []
    n_sents = len(tokens)
    for i, tokens_i in enumerate(tokens):
        if verbose and i % 1000 == 0:
            print('\rconstructing sentence graph {} / {} ...'.format(i, n_sents), end='')
        for j, tokens_j in enumerate(tokens):
            if i >= j:
                continue
            sim = similarity(tokens_i, tokens_j)
            if sim < min_sim:
                continue
            rows.append(i)
            cols.append(j)
            data.append(sim)
    if verbose:
        print('\rconstructing sentence graph was constructed from {} sents'.format(n_sents))
    return csr_matrix((data, (rows, cols)), shape=(n_sents, n_sents))

def textrank_sent_sim(s1, s2):
    """
    Arguments
    ---------
    s1, s2 : list of str
        Tokenized sentences

    Returns
    -------
    Sentence similarity : float
        Non-negative number
    """
    n1 = len(s1)
    n2 = len(s2)
    if (n1 <= 1) or (n2 <= 1):
        return 0
    common = len(set(s1).intersection(set(s2)))
    base = math.log(n1) + math.log(n2)
    return common / base

def cosine_sent_sim(s1, s2):
    """
    Arguments
    ---------
    s1, s2 : list of str
        Tokenized sentences

    Returns
    -------
    Sentence similarity : float
        Non-negative number
    """
    if (not s1) or (not s2):
        return 0

    s1 = Counter(s1)
    s2 = Counter(s2)
    norm1 = math.sqrt(sum(v ** 2 for v in s1.values()))
    norm2 = math.sqrt(sum(v ** 2 for v in s2.values()))
    prod = 0
    for k, v in s1.items():
        prod += v * s2.get(k, 0)
    return prod / (norm1 * norm2)

# %%
import numpy as np


class KeywordSummarizer:
    """
    Arguments
    ---------
    sents : list of str
        Sentence list
    tokenize : callable
        Tokenize function: tokenize(str) = list of str
    min_count : int
        Minumum frequency of words will be used to construct sentence graph
    window : int
        Word cooccurrence window size. Default is -1.
        '-1' means there is cooccurrence between two words if the words occur in a sentence
    min_cooccurrence : int
        Minimum cooccurrence frequency of two words
    vocab_to_idx : dict or None
        Vocabulary to index mapper
    df : float
        PageRank damping factor
    max_iter : int
        Number of PageRank iterations
    verbose : Boolean
        If True, it shows training progress
    """
    def __init__(self, sents=None, tokenize=None, min_count=2,
        window=-1, min_cooccurrence=2, vocab_to_idx=None,
        df=0.85, max_iter=30, verbose=False):

        self.tokenize = tokenize
        self.min_count = min_count
        self.window = window
        self.min_cooccurrence = min_cooccurrence
        self.vocab_to_idx = vocab_to_idx
        self.df = df
        self.max_iter = max_iter
        self.verbose = verbose

        if sents is not None:
            self.train_textrank(sents)

    def train_textrank(self, sents, bias=None):
        """
        Arguments
        ---------
        sents : list of str
            Sentence list
        bias : None or numpy.ndarray
            PageRank bias term

        Returns
        -------
        None
        """

        g, self.idx_to_vocab = word_graph(sents,
            self.tokenize, self.min_count,self.window,
            self.min_cooccurrence, self.vocab_to_idx, self.verbose)
        self.R = pagerank(g, self.df, self.max_iter, bias).reshape(-1)
        if self.verbose:
            print('trained TextRank. n words = {}'.format(self.R.shape[0]))

    def keywords(self, topk=30):
        """
        Arguments
        ---------
        topk : int
            Number of keywords selected from TextRank

        Returns
        -------
        keywords : list of tuple
            Each tuple stands for (word, rank)
        """
        if not hasattr(self, 'R'):
            raise RuntimeError('Train textrank first or use summarize function')
        idxs = self.R.argsort()[-topk:]
        keywords = [(self.idx_to_vocab[idx], self.R[idx]) for idx in reversed(idxs)]
        return keywords

    def summarize(self, sents, topk=30):
        """
        Arguments
        ---------
        sents : list of str
            Sentence list
        topk : int
            Number of keywords selected from TextRank

        Returns
        -------
        keywords : list of tuple
            Each tuple stands for (word, rank)
        """
        self.train_textrank(sents)
        return self.keywords(topk)


class KeysentenceSummarizer:
    """
    Arguments
    ---------
    sents : list of str
        Sentence list
    tokenize : callable
        Tokenize function: tokenize(str) = list of str
    min_count : int
        Minumum frequency of words will be used to construct sentence graph
    min_sim : float
        Minimum similarity between sentences in sentence graph
    similarity : str
        available similarity = ['cosine', 'textrank']
    vocab_to_idx : dict or None
        Vocabulary to index mapper
    df : float
        PageRank damping factor
    max_iter : int
        Number of PageRank iterations
    verbose : Boolean
        If True, it shows training progress
    """
    def __init__(self, sents=None, tokenize=None, min_count=2,
        min_sim=0.3, similarity=None, vocab_to_idx=None,
        df=0.85, max_iter=30, verbose=False):

        self.tokenize = tokenize
        self.min_count = min_count
        self.min_sim = min_sim
        self.similarity = similarity
        self.vocab_to_idx = vocab_to_idx
        self.df = df
        self.max_iter = max_iter
        self.verbose = verbose

        if sents is not None:
            self.train_textrank(sents)

    def train_textrank(self, sents, bias=None):
        """
        Arguments
        ---------
        sents : list of str
            Sentence list
        bias : None or numpy.ndarray
            PageRank bias term
            Shape must be (n_sents,)

        Returns
        -------
        None
        """
        g = sent_graph(sents, self.tokenize, self.min_count,
            self.min_sim, self.similarity, self.vocab_to_idx, self.verbose)
        self.R = pagerank(g, self.df, self.max_iter, bias).reshape(-1)
        if self.verbose:
            print('trained TextRank. n sentences = {}'.format(self.R.shape[0]))

    def summarize(self, sents, topk=30, bias=None):
        """
        Arguments
        ---------
        sents : list of str
            Sentence list
        topk : int
            Number of key-sentences to be selected.
        bias : None or numpy.ndarray
            PageRank bias term
            Shape must be (n_sents,)

        Returns
        -------
        keysents : list of tuple
            Each tuple stands for (sentence index, rank, sentence)

        Usage
        -----
            >>> from textrank import KeysentenceSummarizer

            >>> summarizer = KeysentenceSummarizer(tokenize = tokenizer, min_sim = 0.5)
            >>> keysents = summarizer.summarize(texts, topk=30)
        """
        n_sents = len(sents)
        if isinstance(bias, np.ndarray):
            if bias.shape != (n_sents,):
                raise ValueError('The shape of bias must be (n_sents,) but {}'.format(bias.shape))
        elif bias is not None:
            raise ValueError('The type of bias must be None or numpy.ndarray but the type is {}'.format(type(bias)))

        self.train_textrank(sents, bias)
        idxs = self.R.argsort()[-topk:]
        keysents = [(idx, self.R[idx], sents[idx]) for idx in reversed(idxs)]
        return keysents

# %%
def komoran_tokenize(sent):
    words = sent.split()
    words = [w for w in words if ('/NN' in w or '/XR' in w or '/VA' in w or '/VV' in w)]
    return words

# %%
import pandas as pd

# %%
data = pd.read_csv('sample.csv')
data = data.fillna('')
data.head(3)
# Out:
#     mem_no mem_sex                                         mate_conts  \
# 0        5       m  반갑습니다.  여행과 운동 그리고 음악을 좋아하는 남자입니다. 취미를 함께하며 평생...
# 1  1407510       m  안녕하세요 회사다니며 추말엔 캠핑 다니고 있는 평범한 직장인이에요 처음엔 낯설고 잘...
# 2        2       m  화려한 돌씽입니다. 맘 맞는분 만나서 남은 반생 같이하고 싶습니다.  여행가는것 좋...
#
#                                              komoran
# 0  반갑/VA, 습니다/EF, ./SF, /NA, 여행/NNG, 과/JC, 운동/NNG...
# 1  안녕하세요/IC, 회사/NNG, 다니/VV, 며/EC, 추/NNG, 말/NNG, 에...
# 2  화려/XR, 하/XSA, ㄴ/ETM, 돌/VV, 씽/NNP, 이/VCP, ㅂ니다/E...

# %%
texts = data['komoran'].tolist()
texts
# Out:
# ['반갑/VA, 습니다/EF, ./SF, /NA, 여행/NNG, 과/JC, 운동/NNG, 그리고/MAJ, 음악/NNG, 을/JKO, 좋아하/VV, 는/ETM, 남자/NNG, 이/VCP, ㅂ니다/EF, ./SF, 취미/NNG, 를/JKO, 함께/MAG, 하/XSV, 며/EC, 평생/NNG, 인생/NNG, 의/JKG, 동반자/NNG, 로/JKB, 즐겁/VA, 게/EC, 살/VV, 고/EC, 싶/VX, 습니다/EF, ./SF, /NA, 좋/VA, 은/ETM, 인연/NNG, 이/JKS, 되/VV, 길/NNP, !/SF',
#  '안녕하세요/IC, 회사/NNG, 다니/VV, 며/EC, 추/NNG, 말/NNG, 에/JKB, 는/JX, 캠핑/NNG, 다니/VV, 고/EC, 있/VV, 는/ETM, 평범/XR, 하/XSA, ㄴ/ETM, 직장인/NNG, 이/VCP, 에요/EC, 처음/NNG, 에/JKB, 는/JX, 낯설/VA, 고/EC, 잘/MAG, 모르/VV, 지만/EC, 서로/NNG, 에/JKB, 대하/VV, 아/EC, 알/VV, 아/EC, 가/VX, 면서/EC, 진지/XR, 하/XSA, ㄴ/ETM, 관계/NNG, 로/JKB, 발전/NNG, 하/XSV, 았/EP, 으면/EC, 하/VX, 아요/EC',
#  '화려/XR, 하/XSA, ㄴ/ETM, 돌/VV, 씽/NNP, 이/VCP, ㅂ니다/EF, ./SF, 맘/NNG, 맞/VV, 는/ETM, 분/NNB, 만나/VV, 아서/EC, 남/VV, 은/ETM, 반생/NNG, 같이/MAG, 하/XSV, 고/EC, 싶/VX, 습니다/EF, ./SF, /NA, 여행가/NNG, 이/VCP, 는/ETM, 것/NNB, 좋아하/VV, ㅂ니다/EC',
#  '반갑/VA, 습니다/EF, ./SF, 새롭/VA, ㄴ/ETM, 인연/NNG, 기다리/VV, ㅂ니다/EF, ./SF, 같/VA, 은/ETM, 생각/NNG, 으로/JKB, 같/VA, 은/ETM, 길/NNG, 을/JKO, 가/VV, 았/EP, 으면/EC, 하/VX, ㅂ니다/EF, ./SF',
#  '여보/IC, 이/VCP, 아/EC, 는/JX, 2015/SN, 년/NNB, 에/JKB, 런/NNG, 칭하/VV, 았/EP, 으며/EC, 2022/SN, 년대/NNB, 에/JKB, 는/JX, 4/SN, 만/NR, 쌍/NNG, 의/JKG, 성혼/NNG, 을/JKO, 이루/VV, 도록/EC, 더/MAG, 많/VA, 은/ETM, 홍보/NNG, 를/JKO, 하/VV, 겠/EP, 습니다/EF, ./SF, 많/VA, 은/ETM, 관심/NNG, 부탁드리/VV, ㅂ니다/EF, ./SF',
#  '좋/VA, 은/ETM, 사람/NNG, 좋/VA, 은/ETM, 인연/NNP, 기다리/VV, ㅂ니다/EF, ./SF, 그럼/MAJ, 오늘/NNG, 하루/NNG, 도/JX, ../SE, 즐겁/VA, 고/EC, 행복/NNG, 하/XSV, ㄴ/ETM, 하루/NNG, 되/VV, 세요/EF, ~/SO',
#  '진지/XR, 하/XSA, ㄴ/ETM, 만남/NNG, 을/JKO, 원하/VV, 며/EC, 천천히/MAG, 한/MM, 사람/NNG, 을/JKO, 알/VV, 아/EC, 가/VX, 는/ETM, 걸/VV, ㄹ/ETM, 좋아하/VV, ㅂ니다/EC',
#  '세상/NNG, 의/JKG, 흔하/VA, ㄴ/ETM, 만남/NNG, 보다/JKB, ./SF, 세상/NNG, 에서/JKB, 제일/MAG, 아름답/VA, ㄴ/ETM, 사랑/NNG, 을/JKO, 하/VV, 고/EC, 싶/VX, 습니다/EF, ./SF, 조건/NNG, 따지/VV, 는/ETM, 분/NNB, 은/JX, 패스/NNG',
#  '/NA',
#  '평범/XR, 하/XSA, ㄴ/ETM, 직장/NNG, 여성/NNG, 이/VCP, ㅂ니다/EF, ./SF, 워킹/NNG, 맘/NNG, 으로/JKB, 앞/NNG, 만/JX, 보/VV, 고/EC, 살아오/VV, 았/EP, 는데/EC, 이제/NNG, 는/JX, 진정/NNP, 서로/MAG, 아끼/VV, 는/ETM, 평생/NNG, 의/JKG, 반려자/NNG, 를/JKO, 만나/VV, 아/EC, 노후/NNG, 는/JX, 행복/NNG, 하/XSV, 게/EC, 살/VV, 고/EC, 싶/VX, 습니다/EF, ./SF, 연하/VA, 는/ETM, 싫/VA, 습니다/EC',
#  '착하/VA, 게/EC, 만나/VV, 아/EC, 보/VX, 고/EC, 싶/VX, 어서/EC, 오/VV, 았/EP, 어요/EC, 착하/VA, ㄴ/ETM, 분/NNB, 연락/NNG, 되/XSV, 고/EC, 좋/VA, 겠/EP, 네요/EF, 프로필/NNG, 보/VV, 시/EP, 고/EC, 쪽지/NNG, 주/VV, 세요/EF, ~/SO, 파주/NNP, 운정/NNP, 문산/NNP, 쪽/NNB, 분/NNB, 계시/VV, 면/EC, 좋/VA, 아요/EC',
#  '늦/VA, 은/ETM, 나이/NNG, 까지/JX, 인연/NNG, 을/JKO, 못/MAG, 만나/VV, 고/EC, 있/VX, 네요/EF, ^/SW, ^/SW, ;/SP, ;/SP, 서로/NNG, 에게/JKB, 힘/NNG, 이/JKS, 되/VV, ㄹ/ETM, 수/NNB, 있/VV, 는/ETM, 좋/VA, 은/ETM, 사람/NNG, 을/JKO, 만나/VV, 고/EC, 싶/VX, 습니다/EF, ㅇ/SO, ~/SO, 진지/XR, 하/XSA, ㄴ/ETM, 만남/NNG, 원하/VV, 아요/EC',
#  '매사/NNG, 긍정/NNG, 적/XSN, 이/VCP, 고/EC, 배려/NNG, 심/NNG, 많/VA, 고/EC, 심서/NNG, 미/NNG, 곱/VA, 고/EC, 착하/VA, ㄴ/ETM, 여자/NNG, 이/VCP, ㅂ니다/EC',
#  '편하/VA, 게/EC, 만나/VV, ㄹ/ETM, 수/NNB, 있/VV, 는/ETM, 인연/NNG, 을/JKO, 찾/VV, 고/EC, 싶/VX, 어서/EC, 가입/NNG, 하/XSV, 았/EP, 어요/EC, 진지/XR, 하/XSA, 게/EC, 만나/VV, ㄹ/ETM, 수/NNB, 있/VV, 는/ETM, 사람/NNG, 이/VCP, 면/EC, 좋/VA, 겠/EP, 어요/EC',
#  '69/SN, ~/SO, 71/SN, 년/NNB, 생/XSN, 친구/NNG, 같/VA, 은/ETM, 분/NNB, ,/SP, 별거중/NNG, 이/VCP, 고/EC, 이혼/NNG, 소송/NNG, 중/NNB, 이/VCP, 시/EP, ㄴ/ETM, 분/NNB, 은/JX, 떳떳/XR, 히/NNG, 밝히/VV, 시/EP, 고/EC, 같/VA, 은/ETM, 처지/NNG, 정리/NNG, 안/NNG, 되/XSV, 시/EP, ㄴ/ETM, 여자/NNG, 를/JKO, 만나/VV, 세요/EF, ./SF, 연애/NNG, ,/SP, 동거/NNG, 즐기/VV, 는/ETM, 삶/NNG, 보다/JKB, 는/JX, 함께/MAG, 늙/VV, 어/EC, 가/VX, 며/EC, 서로/NNG, 를/JKO, 책임지/VV, 고/EC, 무덤/NNG, 까지/JX, 함께/MAG, 갈수/NNG, 있/VV, 는/ETM, 짝/NNG, 을/JKO, 만나/VV, 고/EC, 싶/VX, 습니다/EF, ./SF, ./SF, 커리어우먼/NNG, 보/VV, 다는/ETM, 한/MM, 남자/NNG, 의/JKG, 사랑/NNG, 받/VV, 는/ETM, 아내/NNG, 로/JKB, 살/VV, 고/EC, 싶/VX, 습니다/EF, ./SF, 말/NNG, 많/VA, 고/EC, 목소리/NNG, 크/VA, ㄴ/ETM, 남자/NNG, ,/SP, 돌/NNG, 직구/NNG, ,/SP, 매사/NNG, 에/JKB, 트집/NNG, ,/SP, 무능/NNG, 하/XSV, ㅁ/ETN, 과/JKB, 열등감/NNG, ,/SP, 숨기/VV, 는게/EC, 많/VA, 은/ETM, 사람/NNG, ,/SP, 멘탈/NNG, 장애/NNG, 가/JKS, 있/VX, 으시/EP, ㄴ/ETM, 분과/NNG, 는/JX, 인연/NNG, 안/NNG, 되/XSV, 기/ETN, ㄹ/JKO, 바라/VV, ㅂ니다/EC, 가식/NNG, 적/XSN, 이/VCP, ㄴ/ETM, 친절/NNG, 하/XSV, ㅁ/ETN, 아니/VCN, 고/EC, 성품/NNG, 이/JKS, 유/NNG, 하/XSV, 고/EC, ,/SP, 조용/XR, 하/XSA, 시/EP, ㄴ/ETM, 분/NNB, ,/SP, 순수/NNG, 하/XSV, 게/EC, 사랑/NNG, 하/VV, ㄹ/ETM, 수/NNB, 있/VV, 는/ETM, 사람/NNG, 만나/VV, 고/EC, 싶/VX, 어요/EC',
#  '오늘/MAG, 가입/NNG, 하/XSV, 았/EP, 습니다/EF, 평생/NNG, 친구/NNG, 찾/VV, 습니다/EC, 행복/NNG, 하/XSV, 시/EP, 어요/EC, 삶/NNG, 을/JKO, 긍정/NNG, 하/XSV, 고/EC, 즐겁/VA, 게/EC, 사/VV, ㅂ시다/EC, 배우/VV, 는걸/EC, 좋아하/VV, 아요/EC, 지금/MAG, 영어/NNP, 피아노/NNG, 골프/NNG, 배우/VV, 어요/EC, ㅎ/XSA',
#  '미국/NNP, 거주/NNG, 컴퓨터/NNG, 공학/NNG, 박사/NNG, 이/VCP, 며/EC, 현재/MAG, 스타/NNG, 트/VV, 업/NNP, 파/NNG, 운/NNG, 더/MAG, 이/VCP, ㅂ니다/EF, ./SF, 부모/NNG, 님/XSN, 뵈/VV, 어/EC, 한국/NNP, 들어오/VV, 아/EC, 있/VX, 습니다/EF, !/SF',
#  '반갑/VA, 습니다/EF, ^/SW, ^/SW, 좋/VA, 은/ETM, 인연/NNG, 찾아보/VV, ㅂ니다/EF, ./SF, 마음/NNG, 이/JKS, 예쁘/VA, 신/NNP, 분/NNB, ~/SO, 어디/NP, 있/VV, 을까요/EC',
#  '공무원/NNG, 직업/NNG, 확실/XR, 하/XSA, ㄴ/ETM, 분/NNB, 사업/NNG, 하/XSV, 는/ETM, 분/NNB, 싫/VA, 어요/EC, 하/VV, 기/ETN, 크/VA, 고/EC, 지적/NNG, 이/VCP, 고/EC, 통통/XR, 하/XSA, ㄴ/ETM, 스타일/NNG, 이/VCP, ㅂ니다/EC, 귀엽/VA, ㄴ/ETM, 스탈/NNP, 아니/VCN, ㅂ니다/EC, 거짓말/NNG, 하/VV, 는/ETM, 거제/NNP, 일/NNG, 싫어하/VV, 아요/EC, 생각없이/MAG, 문자/NNG, 보내/VV, 는/ETM, 분/NNB, 서로/NNG, 에너지/NNG, 낭비/NNG, 하/VV, 지/EC, 마/VX, ㅂ시다/EC, 모든/MM, 요리/NNG, 다/MAG, 잘/MAG, 하/XSV, 고/EC, 소비/NNG, 성향/NNG, 합리/NNG, 적/XSN, 이/VCP, ㅂ니다/EC, 과소비/NNG, 충동구매/NNG, 안/NNG, 하/XSV, ㅂ니다/EC, 성격/NNG, 상냥/XR, 하/XSA, 고/EC, 좋/VA, 다/EC, 생각/NNG, 하/XSV, ㅂ니다/EC',
#  '/NA',
#  '건강/NNG, 하/XSV, ㄴ/ETM, 마음/NNG, 과/NNG, 건전/XR, 하/XSA, ㄴ/ETM, 생각/NNG, 을/JKO, 가지/VV, 고/EC, 살아가/VV, 는/ETM, 사람/NNG, 이/VCP, ㅂ니다/EC, 주/NNG, 님/XSN, 의/JKG, 나라/NNG, 를/JKO, 섬기/VV, 며/EC, 즐겁/VA, 고/EC, 기쁘/VA, 게/EC, 살아가/VV, 는/ETM, 인/NNG, 이/NP, 이/VCP, ㅂ니다/EC',
#  '우리/NP, 가/JKS, 인생/NNG, 을/JKO, 살아가/VV, 면서/EC, 운명/NNG, 적/XSN, 이/VCP, ㄴ/ETM, 사람/NNG, 을/JKO, 만나/VV, ㄹ/ETM, 수/NNB, 있/VV, 는/ETM, 기회/NNG, 가/JKS, 얼마나/MAG, 되/VV, ㄹ까요/EF, ?/SF, 배우자/NNG, 가/JKS, 운명/NNG, 적/XSN, 이/VCP, ㄴ/ETM, 만남/NNG, 이/JKS, 아니/VCN, ㄹ지라도/EC, 어느/MM, 정도/NNG, 맞추/VV, 어/EC, 가/VX, 며/EC, 살/VV, ㄹ/ETM, 수/NNB, 있/VV, 는/ETM, 사람/NNG, 이/VCP, 면/EC, 좋/VA, 겠/EP, 습니다/EF, ./SF, 만나/VV, 는/ETM, 사람/NNG, 이/JKS, 집착/NNG, 하/XSV, 지/EC, 않/VX, 고/EC, ,/SP, 배려/NNG, 심/XSN, 깊/VA, 은/ETM, 사람/NNG, 이/VCP, 었/EP, 으면/EC, 좋/VA, 겠/EP, 습니다/EF, ./SF, 저/NP, 는/JX, 멀/VA, ㄴ가/EC, 를/JKO, 배우/VV, 는/ETM, 걸/VV, ㄹ/ETM, 좋아하/VV, 고/EC, 하루하루/NNG, 를/JKO, 알차/VA, 게/EC, 보내/VV, 려고/EC, 노력/NNG, 하/XSV, 는/ETM, 사람/NNG, 이/VCP, ㅂ니다/EF, ./SF, 지금/MAG, 꽤/MAG, 공들이/VV, 고/EC, 있/VV, 는/ETM, 취미/NNG, 활동/NNG, 은/JX, 음악/NNG, 영상/NNG, 을/JKO, 만들/VV, 는/ETM, 유튜버입니다./NA, 항상/MAG, 시간/NNG, 에/JKB, 쫓기/VV, 다보니/EC, ,/SP, 귀찮/VA, 아서/EC, 술/NNG, ./SP, 담배/NNG, 를/JKO, 모두/MAG, 끊/VV, 었/EP, 습니다/EF, ./SF, 그런/MM, 시간/NNG, 은/JX, 좋/VA, 은/ETM, 취미/NNG, 활동/NNG, 으로/JKB, 대신/NNG, 채우/VV, 고/EC, 싶/VX, 어요/EF, ./SF, 그냥/MAG, 마음/NNG, 이/JKS, 통하/VV, 는/ETM, 그런/MM, 분/NNB, 만나/VV, 고/EC, 싶/VA, ㅇ/SO',
#  '안녕하세요/IC, ./SF, 저/NP, 는/JX, 건강/NNG, 하/XSV, ㄴ/ETM, 마음/NNG, 의/JKG, 50/SN, 대/NNB, 평범/XR, 하/XSA, ㄴ/ETM, 남자/NNG, 이/VCP, ㅂ니다/EF, ./SF, 서로/NNG, 의/JKG, 일상/NNG, 적/XSN, 이/VCP, ㄴ/ETM, 안부/NNG, 를/JKO, 전하/VV, 고/EC, 보/VX, ㅁ/ETN, 가을/NNG, 에/JKB, 는/JX, 서로/NNG, 의/JKG, 계절/NNG, 감성/NNG, 을/JKO, 나누/VV, 고/EC, 맛있/VA, 는걸/EC, 먹/VV, 게/EC, 되/VV, 면/EC, 두/MM, 손/NNP, 꼭/MAG, 부여잡/VV, 고/EC, 같이/MAG, 오/VV, 고/EC, 싶/VX, 은/ETM, 상대/NNG, 를/JKO, 만나/VV, 면/EC, 좋/VA, 겠/EP, 습니다/EF, ./SF, 상대/NNG, 에게/JKB, 따뜻/XR, 하/XSA, ㄴ/ETM, 마음/NNG, 이/JKS, 되/VV, 어/EC, 주/VX, 고/EC, 싶/VX, 네요/EF, ./SF, 저/NP, 도/JX, 따뜻/XR, 하/XSA, ㄴ/ETM, 마음/NNG, 느끼/VV, 어/EC, 보/VX, 고/EC, 싶/VX, 구요/EF, ^/SW, ^/SW',
#  '초혼/NNG, 이/VCP, ㅂ니다/EF, ./SF, ./SF, 힘들/VA, 다고/EC, 생각/NNG, 하/XSV, 면/EC, 더/MAG, 힘들/VA, 고/EC, 외롭/VA, 다고/EC, 생각/NNG, 하/XSV, 면/EC, 더/MAG, 외롭/VA, 게/EC, 느껴지/VV, ㅂ니다/EC, 하나/NR, 보다/JKB, 는/JX, 둘/NR, 서로/MAG, 의지/NNG, 하/XSV, 고/EC, 남/VV, 은/ETM, 인생/NNG, 즐겁/VA, 게/EC, 보/VV, 네/EC, 시/EP, ㄹ/ETM, 분/NNB, 을/JKO, 기다리/VV, ㅂ니다/EF, ./SF, ./SF, 다른/MM, 것/NNB, ㄴ/JX, 모르/VV, 아도/EC, 성격/NNG, 하/XSV, 나/EC, ㄴ/JX, 쿨하/VA, ㅂ니다/EF, .../SE, 제/NP, 가/JKS, 초혼/NNG, 이/VCP, 라/EC, 초혼/NNP, 만/NNP, 고집/NNG, 하/XSV, 지/EC, 는/JX, 안/VV, 습니다/EF, ./SF, ./SF, ^/SW, 인연/NNG, ^/SW, 만나/VV, 고/EC, 싶/VX, 습니다/EF, Ps/SL, 남/VV, 은/ETM, 인생/NNG, 호수/NNG, 처럼/JKB, 잔잔/XR, 하/XSA, 게/EC, 살/VV, 고/EC, 싶/VX, 습니다/EF, .../SE, ./SF',
#  '좋/VA, 은/ETM, 사람/NNG, 이/JKS, 되/VV, 기/ETN, 위해/NNP, 노력/NNG, 하/XSV, 는/ETM, 한/MM, 사람/NNG, 이/VCP, ㅂ니다/EC, 상대방/NNG, 도/JX, 그렇/VA, 었/EP, 으면/EC, 좋/VA, 겠/EP, 네요/EF',
#  '혼자/NNG, 되/XSV, ㄴ지/EC, 좀/MAG, 되/VV, ㅆ/EP, 습니다/EF, 바쁘/VA, 게/EC, 살/VV, 다보니/EC, 이런/MM, 것/NNB, 도/JX, 모르/VV, 고/EC, 살/VV, 다가/EC, 이제/MAG, 좋/VA, 은/ETM, 분/NNB, 만나/VV, 아서/EC, 조금씩/MAG, 알/VV, 아/EC, 가/VX, 며/EC, 여유/NNG, 롭/XSA, 게/EC, 살/VV, 고/EC, 싶/VX, 네요/EC',
#  '안녕하세요/IC, ./SF, 춘천/NNP, 에서/JKB, 제조업/NNG, 하/XSV, 고/EC, 있/VV, 는/ETM, 30/SN, 살/NNB, 남자/NNG, 이/VCP, ㅂ니다/EF, ./SF',
#  '안녕하세요/IC, ~/SO, 멀/VA, 라/EC, 적/XSN, 이/VCP, 어야/EC, 하/VX, ㄹ지/EF, ./SF, ./SP, ./SP, 일단/MAG, 결혼/NNG, 은/JX, 하/VV, 고/EC, 싶/VX, 습니다/EC, 좋/VA, 아요/EC, 찜/NNG, 버튼/NNG, 이/JKS, 있/VV, 는/ETM, 부분/NNG, 이/VCP, ㄴ지/EC, 모르/VV, 지만/EC, 누르/VV, 어/EC, 주/VX, 세요/EF, ~/SO, ^/SW, ^/SW',
#  '안녕하세요/IC, 모든/MAG, 회원/NNG, 님/XSN, 들/XSN, 반갑/VA, 습니다/EC, 저/NP, 는/JX, 꼭/MAG, 재혼/NNG, 이/JKC, 아니/VCN, 라도/EC, 진정/XR, 하/XSA, ㄴ/ETM, 인생/NNG, 친구/NNG, 이/VCP, 라도/EC, 인연/NNG, 매/VV, 었/EP, 고/EC, 십/NR, 네/XSN, 요/JX, 저/NP, 와/JKB, 같/VA, 은/ETM, 생각/NNG, 하/XSV, 시/EP, ㄴ/ETM, 분/NNB, 손들/VV, 어/EC, 주/VX, 세요/NNP, 제/XSN, 가/JKS, 찻/VV, 아/EC, 가/VV, ㄹ게요/EC',
#  '/NA',
#  '안녕하세요/IC, ^/SW, ^/SW, 좋/VA, 은/ETM, 만남/NNG, 기대/NNG, 하/XSV, ㅂ니다/EC, 말/NNG, 길/VA, 게/EC, 해보/VV, 았/EP, 자/EC, 다/NNG, 것/NNB, 이/VCP, 기/ETN, 서/JKB, 거기/NP, ㄴ/ETM, 것/NNB, 같/VA, 구요/EF, ~/SO, ~/SO, 만나/VV, 면서/EC, 알/VV, 아/EC, 가/VX, 아요/EF, ~/SO, ^/SW, ^/SW',
#  '대화/NNG, 가/JKS, 통하/VV, 는/ETM, 친구/NNG, 를/JKO, 원하/VV, 아/EC, 요서/NNP, 로/JKB, 위로/NNG, 하/XSV, 아/EC, 주/VX, 고/EC, 마음/NNG, 이/JKS, 따뜻/XR, 하/XSA, ㄴ/ETM, 사람/NNG, 이/VCP, 었/EP, 으면/EC, 좋/VA, 겠/EP, 어요/EC',
#  '저/NP, 는/JX, 48/SN, 살/NNB, 노총각/NNG, 이/VCP, ㅂ니다/EC, 저/NP, 와/JKB, 마음/NNG, 맞/VV, 는/ETM, 상대/NNG, 를/JKO, 만나/VV, 아/EC, 평생/NNG, 을/JKO, 함께/MAG, 행복/NNG, 하/XSV, 게/EC, 살/VV, 고/EC, 싶/VX, 습니다/EC',
#  '일/NR, 때문/NNB, 에/JKB, 여기저기/NNG, 다니/VV, 다보니/EC, 인연/NNG, 을/JKO, 만나/VV, 기/ETN, 가/JKS, 힘들/VA, 내/VX, 요/EC, /NA, 혼자/NNG, 영화/NNG, 보고/JKB, 밥/NNG, 먹/VV, 고/EC, 쓸쓸/XR, 하/XSA, 니/EC, 좋/VA, 은/ETM, 인연/NNG, 만나/VV, 아서/EC, /NA, 행복/NNG, 하/XSV, 았/EP, 으면/EC, 좋/VA, 겠/EP, 습니다/EF, 관심/NNG, 많이/MAG, 가지/VV, 어/EC, 주/VX, 시/EP, 어요/EC, ㅎ/XSA, /NA, 경남/NNP, 양산/NNP, 집/NNG, 이나/JC, 경북/NNP, 군위/NNP, 집/NNG, 에/JKB, 주말/NNG, 마다/JX, 내려가/VV, 고/EC, 지금/NNG, 일/NNG, 하/XSV, 는/ETM, 곳/NNG, 은/JX, 경북/NNP, 울진/NNP, 이/VCP, ㅂ니다/EC',
#  '평범/XR, 하/XSA, 고/EC, 평범/XR, 하/XSA, ㄴ/ETM, 분/NNB, 을/JKO, 뵙/VV, 고/EC, 싶/VX, 고/EC, 열심히/MAG, 살/VV, 고/EC, 있/VX, 는/ETM, 청년/NNG, 이/VCP, ㅂ니다/EF, ./SF',
#  '음주/NNG, 못하/VX, 고요/EC, 담배/NNG, 안/NNG, 하/XSV, 고요/EC, 종교/NNG, 없/VA, 고요/EC, 운동/NNG, 좋아하/VV, 고요/EC, 정/NNP, 이/JKS, 많/VA, 다/EC, 요/JX, 외롭/VA, 지/EC, 않/VX, 게/EC, 늘/MAG, 곁/NNG, 에서/JKB, 함께/MAG, 하/VX, ㄹ게요/EF, ./SF, 가끔/MAG, 야구장/NNG, (/SS, 잠실/NNP, ,/SP, 고척/NNP, ,/SP, 수원/NNP, ,/SP, 문학/NNG, )/SS, 데이트/NNG, 가실/NNP, 분/NNB, 환영/NNG, 이/VCP, ㅂ니다/EF, ^/SW, ^/SW',
#  '안녕하세요/IC, ./SF, 잘/MAG, 지내/VV, 요/EC, 근데/MAJ, 이/MM, 앱/NNG, 괜찮/VA, 은/ETM, 것/NNB, ㄴ가요/EF, ?/SF, 반신반의/NNG, 하/VV, 네/EC, 믿/VV, 을/ETM, 수/NNB, 있/VV, 는/ETM, 것/NNB, ㄴ가/EC',
#  '좋/VA, 은/ETM, 사람/NNG, 만/NNB, 이/VCP, 고/EC, 싶/VX, 어/EC, 가입/NNG, 하/XSV, 게/EC, 되/VV, 었/EP, 습니다/EF, /NA, /NA, 결혼/NNG, 하/XSV, ㄹ/ETM, 나이/NNG, 가/JKS, 되/VV, ㄴ/ETM, 것/NNB, 같/VA, 아/EC, 좋/VA, 은/ETM, 인연/NNG, 이/JKS, 되/VV, ㄹ/ETM, 분/NNB, 을/JKO, 만나/VV, 고/EC, 싶/VX, 네요/EC',
#  '항상/MAG, 밝/VA, 고/EC, 즐겁/VA, ㄴ/ETM, 마인드/NNG, 로/JKB, 삶/NNG, 을/JKO, 살/VV, 고/EC, 있/VV, 는/ETM, 한/MM, 남자/NNG, 이/VCP, ㅂ니다/EC',
#  '열심히/MAG, 앞/NNG, 만/JX, 보/VV, 고/EC, 달려오/VV, 다보니/EC, 벌써/MAG, 이렇게/MAG, 되/XSV, 었/EP, 네요/EF, 좋/VA, 은/ETM, 분/NNB, 만나/VV, 아서/EC, 아름답/VA, ㄴ/ETM, 여행/NNG, 같/VA, 은/ETM, 삶/NNG, 을/JKO, 살/VV, 고/EC, 싶/VX, 어요/EC',
#  '앞/NNG, 만/JX, 보/VV, 고/EC, 달리/VV, 어/EC, 시간/NNG, 이/JKS, 이렇/VA, 게/EC, 가/VX, 는지/EC, 도/JX, 모르/VV, 고/EC, 지내/VV, 어서요/EF, ./SF, 늦/VA, 으/EP, 지만/EC, 좋/VA, 은/ETM, 분/NNB, 을/JKO, 만/NNP, 나/NNP, 행복/NNG, 하/XSV, 게/EC, 살/VV, 고/EC, 싶/VX, 습니다/EF, ./SF, 그래도/MAJ, 남/NNP, 대로/NNB, 생활/NNG, 하/XSV, 고/EC, 취미/NNG, 활동/NNG, 을/JKO, 하/VV, 고/EC, 지내/VV, ㄴ/ETM, 것/NNB, 같/VA, 습니다/EF, ./SF, 늦어지/VV, 만/NNP, 평생/NNG, 동고동락/NNG, 하/XSV, 면서/EC, 같이/JKB, 살/NNP, 분/NNB, 을/JKO, 찾/VV, 아요/EC, 사진/NNG, 은/JX, 서로/NNP, 가/JKS, 서산/NNP, 이/NNG, 되/XSV, 고/EC, 공개/NNG, 하/XSV, 게/EC, 습니다/EF, ./SF, 가지/NNB, 것/NNB, 도/JX, 없/VA, 고/EC, 얼굴/NNP, 도/JX, 미/NNP, 남/NNP, 도/JX, 아니/VCN, 다/EF, ./SF, 그냥/MAG, 평범/XR, 하/XSA, ㄴ/ETM, 사람/NNG, 이/VCP, ㅂ니/EP, 자/EC, ^/SW, -/SS, ^/SW, 부디/MAG, 좋/VA, 은/ETM, 분/NNB, 이/VCP, 다가/EC, 와/JC, 조/NNP, 서면/NNG, 하/XSV, ㅂ니다/EF, ./SF',
#  '아무것/NNG, 도/JX, 하/VV, 지/EC, 않/VX, 으면/EC, 아무/MM, 일/NNB, 도/JX, 일어나/VV, 지/EC, 않/VX, 죠/EF, ./SF, 이성/NNG, 과/JC, 만남/NNG, 이/JKS, 힘들/VA, 어/EC, 지/VX, 는/ETM, 나/NP, 이대/NNP, 가/JKS, 되/VV, 었/EP, 어요/EC, 따지/VV, 지/EC, 않/VX, 고요/EF, ./SF, 돌/VV, 싱/NNP, 이/VCP, 시/EP, ㄴ/ETM, 분/NNB, 들/XSN, 도/JX, 상관/NNG, 없/VA, 어요/EC, 여기/NP, 서/JKB, 좋/VA, 은/ETM, 분/NNB, 과/JKB, 함께/MAG, 하/XSA, ㄹ/ETM, 수/NNB, 있/VX, 다면/EC',
#  '/NA',
#  '/NA',
#  '"/SS, 아름답/VA, ㄴ/ETM, 이/MM, 세상/NNG, 소풍/NNG, /NA, 끝내/VV, 는/ETM, 날/NNG, ,/SP, 가/VV, 아서/EC, 아름답/VA, 었/EP, 다고/EC, 말/NNG, 하/XSV, 리라/EC, ~/SO, ~/SO, ~/SO, */SW, 어느/MM, 시인/NNG, 의/JKG, /NA, 글/NNG, 처럼/JKB, 아름답/VA, ㄴ/ETM, 소풍/NNG, 을/JKO, /NA, 함께/MAG, 하/VV, ㄹ/ETM, /NA, 마음/NNG, 따뜻/XR, 하/XSA, ㄴ/ETM, 분/NNB, /NA, 계시/VX, ㄴ가요/EF, ?/SF, 저/NP, 는/JX, /NA, 초/NNB, 중/NNB, 학생/NNG, 들/XSN, 을/JKO, /NA, 지도/NNG, (/SS, 사교육/NNG, )/SS, 하/XSV, 며/EC, /NA, 보람/NNG, 과/JC, /NA, 행복/NNG, 을/JKO, 느끼/VV, 는/ETM, 생활/NNG, 을/JKO, /NA, 하/VV, 고/EC, 있/VX, 어요/EF, ./SF, 항상/MAG, 긍정/NNG, 적/XSN, 으로/JKB, /NA, 생각/NNG, 하/XSV, 고/EC, /NA, 차분/XR, 하/XSA, 며/EC, /NA, 밝/VA, 게/EC, /NA, 잘/MAG, /NA, 웃/VV, 는답니다/EF, ./SF, 결혼/NNG, 보다/JKB, 는/JX, 친구/NNP, 같/VA, 은/ETM, 애인/NNG, /NA, 원하/VV, 구요/EF, ./SF, 전화/NNG, 보다/JKB, 는/JX, /NA, 문자/NNG, 로/JKB, /NA, 소소/XR, 하/XSA, ㄴ/ETM, /NA, 생각/NNG, 과/JC, /NA, 따뜻/XR, 하/XSA, ㄴ/ETM, /NA, 마음/NNG, 주/VX, 고/EC, 받/VV, 을/ETM, /NA, 수/NNB, 있/VV, 는/ETM, 분/NNB, /NA, 원하/VV, 아요/EF, ./SF, /NA, 연하/VA, 는/ETM, 사절/NNG, ~/SO',
#  '안녕하십니까~~･ 평생 서로에게 도움되고서로에게 따뜻함과 의지가 될수있는 만남이 되었으면 좋겠습니다. /NA',
#  '몸과마음이온화하며착해요서로거짓없고잇는그대로친구처럼연인갇이사귀어보실분희망해요문자는못하니메세지남겨놓으면연락드리겟으요죄송해요/NA',
#  '여자/NNG, 에게/JKB, 상처/NNG, 를/JKO, 받/VV, 고/EC, 믿/VV, 고/EC, 결혼/NNG, 을/JKO, 하/VV, 았/EP, 는데/EC, 사기/NNG, 를/JKO, 당하/VV, 아서/EC, 이혼/NNG, 을/JKO, 결심/NNG, 하/XSV, 게/EC, 되/VX, 었/EP, 습니다/EF, ./SF, 가정/NNG, 의/JKG, 무/XPN, 관심/NNG, 적/XSN, 이/VCP, ㄴ/ETM, 여자/NNG, 는/JX, 딱/MAG, 질색/NNG, 이/VCP, ㅂ니다/EF, ./SF',
#  '안녕하세요/IC, 반갑/VA, 습니다/EC, 서로/MAG, 인연/NNG, 으로/JKB, 만나/VV, 아서/EC, 손/NNG, 꼭/MAG, 잡/VV, 고/EC, 남/VV, 은/ETM, 인생/NNG, 즐기/VV, 며/EC, 행복/NNG, 하/XSV, 게/EC, 아끼/VV, 어/EC, 주/VX, 며/EC, 살아가/VV, 고/EC, 싶/VX, 습니다/EF, ./SF',
#  '제/MM, 소개/NNG, 를/JKO, 글/NNG, 로써/JKB, 장황/XR, 하/XSA, 게/EC, 작성/NNG, 하/XSV, 기/ETN, 보다/JKB, 는/JX, 단도직입/NNG, 적/XSN, 으로/JKB, 연락/NNG, 하/XSV, 고/EC, 만나/VV, 아서/EC, 알/VV, 아/EC, 가/VX, 고/EC, 싶/VX, 어요/EC, 그/NP, 게/JKB, 더/MAG, 의미/NNG, 있/VV, 다고/EC, 생각/NNG, 되/XSV, ㅂ니다/EC, 느낌/NNG, 적/XSN, 이/VCP, ㄴ/ETM, 느낌/NNG, ?/SF']

# %%
for cde in texts:
    f_lst = get_lst(cde)
# Out:
# ['반갑/VA', '습니다/EF', './SF', '/NA', '여행/NNG', '과/JC', '운동/NNG', '그리고/MAJ', '음악/NNG', '을/JKO', '좋아하/VV', '는/ETM', '남자/NNG', '이/VCP', 'ㅂ니다/EF', './SF', '취미/NNG', '를/JKO', '함께/MAG', '하/XSV', '며/EC', '평생/NNG', '인생/NNG', '의/JKG', '동반자/NNG', '로/JKB', '즐겁/VA', '게/EC', '살/VV', '고/EC', '싶/VX', '습니다/EF', './SF', '/NA', '좋/VA', '은/ETM', '인연/NNG', '이/JKS', '되/VV', '길/NNP', '!/SF']
# ['안녕하세요/IC', '회사/NNG', '다니/VV', '며/EC', '추/NNG', '말/NNG', '에/JKB', '는/JX', '캠핑/NNG', '다니/VV', '고/EC', '있/VV', '는/ETM', '평범/XR', '하/XSA', 'ㄴ/ETM', '직장인/NNG', '이/VCP', '에요/EC', '처음/NNG', '에/JKB', '는/JX', '낯설/VA', '고/EC', '잘/MAG', '모르/VV', '지만/EC', '서로/NNG', '에/JKB', '대하/VV', '아/EC', '알/VV', '아/EC', '가/VX', '면서/EC', '진지/XR', '하/XSA', 'ㄴ/ETM', '관계/NNG', '로/JKB', '발전/NNG', '하/XSV', '았/EP', '으면/EC', '하/VX', '아요/EC']
# ['화려/XR', '하/XSA', 'ㄴ/ETM', '돌/VV', '씽/NNP', '이/VCP', 'ㅂ니다/EF', './SF', '맘/NNG', '맞/VV', '는/ETM', '분/NNB', '만나/VV', '아서/EC', '남/VV', '은/ETM', '반생/NNG', '같이/MAG', '하/XSV', '고/EC', '싶/VX', '습니다/EF', './SF', '/NA', '여행가/NNG', '이/VCP', '는/ETM', '것/NNB', '좋아하/VV', 'ㅂ니다/EC']
# ['반갑/VA', '습니다/EF', './SF', '새롭/VA', 'ㄴ/ETM', '인연/NNG', '기다리/VV', 'ㅂ니다/EF', './SF', '같/VA', '은/ETM', '생각/NNG', '으로/JKB', '같/VA', '은/ETM', '길/NNG', '을/JKO', '가/VV', '았/EP', '으면/EC', '하/VX', 'ㅂ니다/EF', './SF']
# ['여보/IC', '이/VCP', '아/EC', '는/JX', '2015/SN', '년/NNB', '에/JKB', '런/NNG', '칭하/VV', '았/EP', '으며/EC', '2022/SN', '년대/NNB', '에/JKB', '는/JX', '4/SN', '만/NR', '쌍/NNG', '의/JKG', '성혼/NNG', '을/JKO', '이루/VV', '도록/EC', '더/MAG', '많/VA', '은/ETM', '홍보/NNG', '를/JKO', '하/VV', '겠/EP', '습니다/EF', './SF', '많/VA', '은/ETM', '관심/NNG', '부탁드리/VV', 'ㅂ니다/EF', './SF']
# ['좋/VA', '은/ETM', '사람/NNG', '좋/VA', '은/ETM', '인연/NNP', '기다리/VV', 'ㅂ니다/EF', './SF', '그럼/MAJ', '오늘/NNG', '하루/NNG', '도/JX', '../SE', '즐겁/VA', '고/EC', '행복/NNG', '하/XSV', 'ㄴ/ETM', '하루/NNG', '되/VV', '세요/EF', '~/SO']
# ['진지/XR', '하/XSA', 'ㄴ/ETM', '만남/NNG', '을/JKO', '원하/VV', '며/EC', '천천히/MAG', '한/MM', '사람/NNG', '을/JKO', '알/VV', '아/EC', '가/VX', '는/ETM', '걸/VV', 'ㄹ/ETM', '좋아하/VV', 'ㅂ니다/EC']
# ['세상/NNG', '의/JKG', '흔하/VA', 'ㄴ/ETM', '만남/NNG', '보다/JKB', './SF', '세상/NNG', '에서/JKB', '제일/MAG', '아름답/VA', 'ㄴ/ETM', '사랑/NNG', '을/JKO', '하/VV', '고/EC', '싶/VX', '습니다/EF', './SF', '조건/NNG', '따지/VV', '는/ETM', '분/NNB', '은/JX', '패스/NNG']
# ['/NA']
# ['평범/XR', '하/XSA', 'ㄴ/ETM', '직장/NNG', '여성/NNG', '이/VCP', 'ㅂ니다/EF', './SF', '워킹/NNG', '맘/NNG', '으로/JKB', '앞/NNG', '만/JX', '보/VV', '고/EC', '살아오/VV', '았/EP', '는데/EC', '이제/NNG', '는/JX', '진정/NNP', '서로/MAG', '아끼/VV', '는/ETM', '평생/NNG', '의/JKG', '반려자/NNG', '를/JKO', '만나/VV', '아/EC', '노후/NNG', '는/JX', '행복/NNG', '하/XSV', '게/EC', '살/VV', '고/EC', '싶/VX', '습니다/EF', './SF', '연하/VA', '는/ETM', '싫/VA', '습니다/EC']
# ['착하/VA', '게/EC', '만나/VV', '아/EC', '보/VX', '고/EC', '싶/VX', '어서/EC', '오/VV', '았/EP', '어요/EC', '착하/VA', 'ㄴ/ETM', '분/NNB', '연락/NNG', '되/XSV', '고/EC', '좋/VA', '겠/EP', '네요/EF', '프로필/NNG', '보/VV', '시/EP', '고/EC', '쪽지/NNG', '주/VV', '세요/EF', '~/SO', '파주/NNP', '운정/NNP', '문산/NNP', '쪽/NNB', '분/NNB', '계시/VV', '면/EC', '좋/VA', '아요/EC']
# ['늦/VA', '은/ETM', '나이/NNG', '까지/JX', '인연/NNG', '을/JKO', '못/MAG', '만나/VV', '고/EC', '있/VX', '네요/EF', '^/SW', '^/SW', ';/SP', ';/SP', '서로/NNG', '에게/JKB', '힘/NNG', '이/JKS', '되/VV', 'ㄹ/ETM', '수/NNB', '있/VV', '는/ETM', '좋/VA', '은/ETM', '사람/NNG', '을/JKO', '만나/VV', '고/EC', '싶/VX', '습니다/EF', 'ㅇ/SO', '~/SO', '진지/XR', '하/XSA', 'ㄴ/ETM', '만남/NNG', '원하/VV', '아요/EC']
# ['매사/NNG', '긍정/NNG', '적/XSN', '이/VCP', '고/EC', '배려/NNG', '심/NNG', '많/VA', '고/EC', '심서/NNG', '미/NNG', '곱/VA', '고/EC', '착하/VA', 'ㄴ/ETM', '여자/NNG', '이/VCP', 'ㅂ니다/EC']
# ['편하/VA', '게/EC', '만나/VV', 'ㄹ/ETM', '수/NNB', '있/VV', '는/ETM', '인연/NNG', '을/JKO', '찾/VV', '고/EC', '싶/VX', '어서/EC', '가입/NNG', '하/XSV', '았/EP', '어요/EC', '진지/XR', '하/XSA', '게/EC', '만나/VV', 'ㄹ/ETM', '수/NNB', '있/VV', '는/ETM', '사람/NNG', '이/VCP', '면/EC', '좋/VA', '겠/EP', '어요/EC']
# ['69/SN', '~/SO', '71/SN', '년/NNB', '생/XSN', '친구/NNG', '같/VA', '은/ETM', '분/NNB', '', '/SP', '별거중/NNG', '이/VCP', '고/EC', '이혼/NNG', '소송/NNG', '중/NNB', '이/VCP', '시/EP', 'ㄴ/ETM', '분/NNB', '은/JX', '떳떳/XR', '히/NNG', '밝히/VV', '시/EP', '고/EC', '같/VA', '은/ETM', '처지/NNG', '정리/NNG', '안/NNG', '되/XSV', '시/EP', 'ㄴ/ETM', '여자/NNG', '를/JKO', '만나/VV', '세요/EF', './SF', '연애/NNG', '', '/SP', '동거/NNG', '즐기/VV', '는/ETM', '삶/NNG', '보다/JKB', '는/JX', '함께/MAG', '늙/VV', '어/EC', '가/VX', '며/EC', '서로/NNG', '를/JKO', '책임지/VV', '고/EC', '무덤/NNG', '까지/JX', '함께/MAG', '갈수/NNG', '있/VV', '는/ETM', '짝/NNG', '을/JKO', '만나/VV', '고/EC', '싶/VX', '습니다/EF', './SF', './SF', '커리어우먼/NNG', '보/VV', '다는/ETM', '한/MM', '남자/NNG', '의/JKG', '사랑/NNG', '받/VV', '는/ETM', '아내/NNG', '로/JKB', '살/VV', '고/EC', '싶/VX', '습니다/EF', './SF', '말/NNG', '많/VA', '고/EC', '목소리/NNG', '크/VA', 'ㄴ/ETM', '남자/NNG', '', '/SP', '돌/NNG', '직구/NNG', '', '/SP', '매사/NNG', '에/JKB', '트집/NNG', '', '/SP', '무능/NNG', '하/XSV', 'ㅁ/ETN', '과/JKB', '열등감/NNG', '', '/SP', '숨기/VV', '는게/EC', '많/VA', '은/ETM', '사람/NNG', '', '/SP', '멘탈/NNG', '장애/NNG', '가/JKS', '있/VX', '으시/EP', 'ㄴ/ETM', '분과/NNG', '는/JX', '인연/NNG', '안/NNG', '되/XSV', '기/ETN', 'ㄹ/JKO', '바라/VV', 'ㅂ니다/EC', '가식/NNG', '적/XSN', '이/VCP', 'ㄴ/ETM', '친절/NNG', '하/XSV', 'ㅁ/ETN', '아니/VCN', '고/EC', '성품/NNG', '이/JKS', '유/NNG', '하/XSV', '고/EC', '', '/SP', '조용/XR', '하/XSA', '시/EP', 'ㄴ/ETM', '분/NNB', '', '/SP', '순수/NNG', '하/XSV', '게/EC', '사랑/NNG', '하/VV', 'ㄹ/ETM', '수/NNB', '있/VV', '는/ETM', '사람/NNG', '만나/VV', '고/EC', '싶/VX', '어요/EC']
# ['오늘/MAG', '가입/NNG', '하/XSV', '았/EP', '습니다/EF', '평생/NNG', '친구/NNG', '찾/VV', '습니다/EC', '행복/NNG', '하/XSV', '시/EP', '어요/EC', '삶/NNG', '을/JKO', '긍정/NNG', '하/XSV', '고/EC', '즐겁/VA', '게/EC', '사/VV', 'ㅂ시다/EC', '배우/VV', '는걸/EC', '좋아하/VV', '아요/EC', '지금/MAG', '영어/NNP', '피아노/NNG', '골프/NNG', '배우/VV', '어요/EC', 'ㅎ/XSA']
# ['미국/NNP', '거주/NNG', '컴퓨터/NNG', '공학/NNG', '박사/NNG', '이/VCP', '며/EC', '현재/MAG', '스타/NNG', '트/VV', '업/NNP', '파/NNG', '운/NNG', '더/MAG', '이/VCP', 'ㅂ니다/EF', './SF', '부모/NNG', '님/XSN', '뵈/VV', '어/EC', '한국/NNP', '들어오/VV', '아/EC', '있/VX', '습니다/EF', '!/SF']
# ['반갑/VA', '습니다/EF', '^/SW', '^/SW', '좋/VA', '은/ETM', '인연/NNG', '찾아보/VV', 'ㅂ니다/EF', './SF', '마음/NNG', '이/JKS', '예쁘/VA', '신/NNP', '분/NNB', '~/SO', '어디/NP', '있/VV', '을까요/EC']
# ['공무원/NNG', '직업/NNG', '확실/XR', '하/XSA', 'ㄴ/ETM', '분/NNB', '사업/NNG', '하/XSV', '는/ETM', '분/NNB', '싫/VA', '어요/EC', '하/VV', '기/ETN', '크/VA', '고/EC', '지적/NNG', '이/VCP', '고/EC', '통통/XR', '하/XSA', 'ㄴ/ETM', '스타일/NNG', '이/VCP', 'ㅂ니다/EC', '귀엽/VA', 'ㄴ/ETM', '스탈/NNP', '아니/VCN', 'ㅂ니다/EC', '거짓말/NNG', '하/VV', '는/ETM', '거제/NNP', '일/NNG', '싫어하/VV', '아요/EC', '생각없이/MAG', '문자/NNG', '보내/VV', '는/ETM', '분/NNB', '서로/NNG', '에너지/NNG', '낭비/NNG', '하/VV', '지/EC', '마/VX', 'ㅂ시다/EC', '모든/MM', '요리/NNG', '다/MAG', '잘/MAG', '하/XSV', '고/EC', '소비/NNG', '성향/NNG', '합리/NNG', '적/XSN', '이/VCP', 'ㅂ니다/EC', '과소비/NNG', '충동구매/NNG', '안/NNG', '하/XSV', 'ㅂ니다/EC', '성격/NNG', '상냥/XR', '하/XSA', '고/EC', '좋/VA', '다/EC', '생각/NNG', '하/XSV', 'ㅂ니다/EC']
# ['/NA']
# ['건강/NNG', '하/XSV', 'ㄴ/ETM', '마음/NNG', '과/NNG', '건전/XR', '하/XSA', 'ㄴ/ETM', '생각/NNG', '을/JKO', '가지/VV', '고/EC', '살아가/VV', '는/ETM', '사람/NNG', '이/VCP', 'ㅂ니다/EC', '주/NNG', '님/XSN', '의/JKG', '나라/NNG', '를/JKO', '섬기/VV', '며/EC', '즐겁/VA', '고/EC', '기쁘/VA', '게/EC', '살아가/VV', '는/ETM', '인/NNG', '이/NP', '이/VCP', 'ㅂ니다/EC']
# ['우리/NP', '가/JKS', '인생/NNG', '을/JKO', '살아가/VV', '면서/EC', '운명/NNG', '적/XSN', '이/VCP', 'ㄴ/ETM', '사람/NNG', '을/JKO', '만나/VV', 'ㄹ/ETM', '수/NNB', '있/VV', '는/ETM', '기회/NNG', '가/JKS', '얼마나/MAG', '되/VV', 'ㄹ까요/EF', '?/SF', '배우자/NNG', '가/JKS', '운명/NNG', '적/XSN', '이/VCP', 'ㄴ/ETM', '만남/NNG', '이/JKS', '아니/VCN', 'ㄹ지라도/EC', '어느/MM', '정도/NNG', '맞추/VV', '어/EC', '가/VX', '며/EC', '살/VV', 'ㄹ/ETM', '수/NNB', '있/VV', '는/ETM', '사람/NNG', '이/VCP', '면/EC', '좋/VA', '겠/EP', '습니다/EF', './SF', '만나/VV', '는/ETM', '사람/NNG', '이/JKS', '집착/NNG', '하/XSV', '지/EC', '않/VX', '고/EC', '', '/SP', '배려/NNG', '심/XSN', '깊/VA', '은/ETM', '사람/NNG', '이/VCP', '었/EP', '으면/EC', '좋/VA', '겠/EP', '습니다/EF', './SF', '저/NP', '는/JX', '멀/VA', 'ㄴ가/EC', '를/JKO', '배우/VV', '는/ETM', '걸/VV', 'ㄹ/ETM', '좋아하/VV', '고/EC', '하루하루/NNG', '를/JKO', '알차/VA', '게/EC', '보내/VV', '려고/EC', '노력/NNG', '하/XSV', '는/ETM', '사람/NNG', '이/VCP', 'ㅂ니다/EF', './SF', '지금/MAG', '꽤/MAG', '공들이/VV', '고/EC', '있/VV', '는/ETM', '취미/NNG', '활동/NNG', '은/JX', '음악/NNG', '영상/NNG', '을/JKO', '만들/VV', '는/ETM', '유튜버입니다./NA', '항상/MAG', '시간/NNG', '에/JKB', '쫓기/VV', '다보니/EC', '', '/SP', '귀찮/VA', '아서/EC', '술/NNG', './SP', '담배/NNG', '를/JKO', '모두/MAG', '끊/VV', '었/EP', '습니다/EF', './SF', '그런/MM', '시간/NNG', '은/JX', '좋/VA', '은/ETM', '취미/NNG', '활동/NNG', '으로/JKB', '대신/NNG', '채우/VV', '고/EC', '싶/VX', '어요/EF', './SF', '그냥/MAG', '마음/NNG', '이/JKS', '통하/VV', '는/ETM', '그런/MM', '분/NNB', '만나/VV', '고/EC', '싶/VA', 'ㅇ/SO']
# ['안녕하세요/IC', './SF', '저/NP', '는/JX', '건강/NNG', '하/XSV', 'ㄴ/ETM', '마음/NNG', '의/JKG', '50/SN', '대/NNB', '평범/XR', '하/XSA', 'ㄴ/ETM', '남자/NNG', '이/VCP', 'ㅂ니다/EF', './SF', '서로/NNG', '의/JKG', '일상/NNG', '적/XSN', '이/VCP', 'ㄴ/ETM', '안부/NNG', '를/JKO', '전하/VV', '고/EC', '보/VX', 'ㅁ/ETN', '가을/NNG', '에/JKB', '는/JX', '서로/NNG', '의/JKG', '계절/NNG', '감성/NNG', '을/JKO', '나누/VV', '고/EC', '맛있/VA', '는걸/EC', '먹/VV', '게/EC', '되/VV', '면/EC', '두/MM', '손/NNP', '꼭/MAG', '부여잡/VV', '고/EC', '같이/MAG', '오/VV', '고/EC', '싶/VX', '은/ETM', '상대/NNG', '를/JKO', '만나/VV', '면/EC', '좋/VA', '겠/EP', '습니다/EF', './SF', '상대/NNG', '에게/JKB', '따뜻/XR', '하/XSA', 'ㄴ/ETM', '마음/NNG', '이/JKS', '되/VV', '어/EC', '주/VX', '고/EC', '싶/VX', '네요/EF', './SF', '저/NP', '도/JX', '따뜻/XR', '하/XSA', 'ㄴ/ETM', '마음/NNG', '느끼/VV', '어/EC', '보/VX', '고/EC', '싶/VX', '구요/EF', '^/SW', '^/SW']
# ['초혼/NNG', '이/VCP', 'ㅂ니다/EF', './SF', './SF', '힘들/VA', '다고/EC', '생각/NNG', '하/XSV', '면/EC', '더/MAG', '힘들/VA', '고/EC', '외롭/VA', '다고/EC', '생각/NNG', '하/XSV', '면/EC', '더/MAG', '외롭/VA', '게/EC', '느껴지/VV', 'ㅂ니다/EC', '하나/NR', '보다/JKB', '는/JX', '둘/NR', '서로/MAG', '의지/NNG', '하/XSV', '고/EC', '남/VV', '은/ETM', '인생/NNG', '즐겁/VA', '게/EC', '보/VV', '네/EC', '시/EP', 'ㄹ/ETM', '분/NNB', '을/JKO', '기다리/VV', 'ㅂ니다/EF', './SF', './SF', '다른/MM', '것/NNB', 'ㄴ/JX', '모르/VV', '아도/EC', '성격/NNG', '하/XSV', '나/EC', 'ㄴ/JX', '쿨하/VA', 'ㅂ니다/EF', '.../SE', '제/NP', '가/JKS', '초혼/NNG', '이/VCP', '라/EC', '초혼/NNP', '만/NNP', '고집/NNG', '하/XSV', '지/EC', '는/JX', '안/VV', '습니다/EF', './SF', './SF', '^/SW', '인연/NNG', '^/SW', '만나/VV', '고/EC', '싶/VX', '습니다/EF', 'Ps/SL', '남/VV', '은/ETM', '인생/NNG', '호수/NNG', '처럼/JKB', '잔잔/XR', '하/XSA', '게/EC', '살/VV', '고/EC', '싶/VX', '습니다/EF', '.../SE', './SF']
# ['좋/VA', '은/ETM', '사람/NNG', '이/JKS', '되/VV', '기/ETN', '위해/NNP', '노력/NNG', '하/XSV', '는/ETM', '한/MM', '사람/NNG', '이/VCP', 'ㅂ니다/EC', '상대방/NNG', '도/JX', '그렇/VA', '었/EP', '으면/EC', '좋/VA', '겠/EP', '네요/EF']
# ['혼자/NNG', '되/XSV', 'ㄴ지/EC', '좀/MAG', '되/VV', 'ㅆ/EP', '습니다/EF', '바쁘/VA', '게/EC', '살/VV', '다보니/EC', '이런/MM', '것/NNB', '도/JX', '모르/VV', '고/EC', '살/VV', '다가/EC', '이제/MAG', '좋/VA', '은/ETM', '분/NNB', '만나/VV', '아서/EC', '조금씩/MAG', '알/VV', '아/EC', '가/VX', '며/EC', '여유/NNG', '롭/XSA', '게/EC', '살/VV', '고/EC', '싶/VX', '네요/EC']
# ['안녕하세요/IC', './SF', '춘천/NNP', '에서/JKB', '제조업/NNG', '하/XSV', '고/EC', '있/VV', '는/ETM', '30/SN', '살/NNB', '남자/NNG', '이/VCP', 'ㅂ니다/EF', './SF']
# ['안녕하세요/IC', '~/SO', '멀/VA', '라/EC', '적/XSN', '이/VCP', '어야/EC', '하/VX', 'ㄹ지/EF', './SF', './SP', './SP', '일단/MAG', '결혼/NNG', '은/JX', '하/VV', '고/EC', '싶/VX', '습니다/EC', '좋/VA', '아요/EC', '찜/NNG', '버튼/NNG', '이/JKS', '있/VV', '는/ETM', '부분/NNG', '이/VCP', 'ㄴ지/EC', '모르/VV', '지만/EC', '누르/VV', '어/EC', '주/VX', '세요/EF', '~/SO', '^/SW', '^/SW']
# ['안녕하세요/IC', '모든/MAG', '회원/NNG', '님/XSN', '들/XSN', '반갑/VA', '습니다/EC', '저/NP', '는/JX', '꼭/MAG', '재혼/NNG', '이/JKC', '아니/VCN', '라도/EC', '진정/XR', '하/XSA', 'ㄴ/ETM', '인생/NNG', '친구/NNG', '이/VCP', '라도/EC', '인연/NNG', '매/VV', '었/EP', '고/EC', '십/NR', '네/XSN', '요/JX', '저/NP', '와/JKB', '같/VA', '은/ETM', '생각/NNG', '하/XSV', '시/EP', 'ㄴ/ETM', '분/NNB', '손들/VV', '어/EC', '주/VX', '세요/NNP', '제/XSN', '가/JKS', '찻/VV', '아/EC', '가/VV', 'ㄹ게요/EC']
# ['/NA']
# ['안녕하세요/IC', '^/SW', '^/SW', '좋/VA', '은/ETM', '만남/NNG', '기대/NNG', '하/XSV', 'ㅂ니다/EC', '말/NNG', '길/VA', '게/EC', '해보/VV', '았/EP', '자/EC', '다/NNG', '것/NNB', '이/VCP', '기/ETN', '서/JKB', '거기/NP', 'ㄴ/ETM', '것/NNB', '같/VA', '구요/EF', '~/SO', '~/SO', '만나/VV', '면서/EC', '알/VV', '아/EC', '가/VX', '아요/EF', '~/SO', '^/SW', '^/SW']
# ['대화/NNG', '가/JKS', '통하/VV', '는/ETM', '친구/NNG', '를/JKO', '원하/VV', '아/EC', '요서/NNP', '로/JKB', '위로/NNG', '하/XSV', '아/EC', '주/VX', '고/EC', '마음/NNG', '이/JKS', '따뜻/XR', '하/XSA', 'ㄴ/ETM', '사람/NNG', '이/VCP', '었/EP', '으면/EC', '좋/VA', '겠/EP', '어요/EC']
# ['저/NP', '는/JX', '48/SN', '살/NNB', '노총각/NNG', '이/VCP', 'ㅂ니다/EC', '저/NP', '와/JKB', '마음/NNG', '맞/VV', '는/ETM', '상대/NNG', '를/JKO', '만나/VV', '아/EC', '평생/NNG', '을/JKO', '함께/MAG', '행복/NNG', '하/XSV', '게/EC', '살/VV', '고/EC', '싶/VX', '습니다/EC']
# ['일/NR', '때문/NNB', '에/JKB', '여기저기/NNG', '다니/VV', '다보니/EC', '인연/NNG', '을/JKO', '만나/VV', '기/ETN', '가/JKS', '힘들/VA', '내/VX', '요/EC', '/NA', '혼자/NNG', '영화/NNG', '보고/JKB', '밥/NNG', '먹/VV', '고/EC', '쓸쓸/XR', '하/XSA', '니/EC', '좋/VA', '은/ETM', '인연/NNG', '만나/VV', '아서/EC', '/NA', '행복/NNG', '하/XSV', '았/EP', '으면/EC', '좋/VA', '겠/EP', '습니다/EF', '관심/NNG', '많이/MAG', '가지/VV', '어/EC', '주/VX', '시/EP', '어요/EC', 'ㅎ/XSA', '/NA', '경남/NNP', '양산/NNP', '집/NNG', '이나/JC', '경북/NNP', '군위/NNP', '집/NNG', '에/JKB', '주말/NNG', '마다/JX', '내려가/VV', '고/EC', '지금/NNG', '일/NNG', '하/XSV', '는/ETM', '곳/NNG', '은/JX', '경북/NNP', '울진/NNP', '이/VCP', 'ㅂ니다/EC']
# ['평범/XR', '하/XSA', '고/EC', '평범/XR', '하/XSA', 'ㄴ/ETM', '분/NNB', '을/JKO', '뵙/VV', '고/EC', '싶/VX', '고/EC', '열심히/MAG', '살/VV', '고/EC', '있/VX', '는/ETM', '청년/NNG', '이/VCP', 'ㅂ니다/EF', './SF']
# ['음주/NNG', '못하/VX', '고요/EC', '담배/NNG', '안/NNG', '하/XSV', '고요/EC', '종교/NNG', '없/VA', '고요/EC', '운동/NNG', '좋아하/VV', '고요/EC', '정/NNP', '이/JKS', '많/VA', '다/EC', '요/JX', '외롭/VA', '지/EC', '않/VX', '게/EC', '늘/MAG', '곁/NNG', '에서/JKB', '함께/MAG', '하/VX', 'ㄹ게요/EF', './SF', '가끔/MAG', '야구장/NNG', '(/SS', '잠실/NNP', '', '/SP', '고척/NNP', '', '/SP', '수원/NNP', '', '/SP', '문학/NNG', ')/SS', '데이트/NNG', '가실/NNP', '분/NNB', '환영/NNG', '이/VCP', 'ㅂ니다/EF', '^/SW', '^/SW']
# ['안녕하세요/IC', './SF', '잘/MAG', '지내/VV', '요/EC', '근데/MAJ', '이/MM', '앱/NNG', '괜찮/VA', '은/ETM', '것/NNB', 'ㄴ가요/EF', '?/SF', '반신반의/NNG', '하/VV', '네/EC', '믿/VV', '을/ETM', '수/NNB', '있/VV', '는/ETM', '것/NNB', 'ㄴ가/EC']
# ['좋/VA', '은/ETM', '사람/NNG', '만/NNB', '이/VCP', '고/EC', '싶/VX', '어/EC', '가입/NNG', '하/XSV', '게/EC', '되/VV', '었/EP', '습니다/EF', '/NA', '/NA', '결혼/NNG', '하/XSV', 'ㄹ/ETM', '나이/NNG', '가/JKS', '되/VV', 'ㄴ/ETM', '것/NNB', '같/VA', '아/EC', '좋/VA', '은/ETM', '인연/NNG', '이/JKS', '되/VV', 'ㄹ/ETM', '분/NNB', '을/JKO', '만나/VV', '고/EC', '싶/VX', '네요/EC']
# ['항상/MAG', '밝/VA', '고/EC', '즐겁/VA', 'ㄴ/ETM', '마인드/NNG', '로/JKB', '삶/NNG', '을/JKO', '살/VV', '고/EC', '있/VV', '는/ETM', '한/MM', '남자/NNG', '이/VCP', 'ㅂ니다/EC']
# ['열심히/MAG', '앞/NNG', '만/JX', '보/VV', '고/EC', '달려오/VV', '다보니/EC', '벌써/MAG', '이렇게/MAG', '되/XSV', '었/EP', '네요/EF', '좋/VA', '은/ETM', '분/NNB', '만나/VV', '아서/EC', '아름답/VA', 'ㄴ/ETM', '여행/NNG', '같/VA', '은/ETM', '삶/NNG', '을/JKO', '살/VV', '고/EC', '싶/VX', '어요/EC']
# ['앞/NNG', '만/JX', '보/VV', '고/EC', '달리/VV', '어/EC', '시간/NNG', '이/JKS', '이렇/VA', '게/EC', '가/VX', '는지/EC', '도/JX', '모르/VV', '고/EC', '지내/VV', '어서요/EF', './SF', '늦/VA', '으/EP', '지만/EC', '좋/VA', '은/ETM', '분/NNB', '을/JKO', '만/NNP', '나/NNP', '행복/NNG', '하/XSV', '게/EC', '살/VV', '고/EC', '싶/VX', '습니다/EF', './SF', '그래도/MAJ', '남/NNP', '대로/NNB', '생활/NNG', '하/XSV', '고/EC', '취미/NNG', '활동/NNG', '을/JKO', '하/VV', '고/EC', '지내/VV', 'ㄴ/ETM', '것/NNB', '같/VA', '습니다/EF', './SF', '늦어지/VV', '만/NNP', '평생/NNG', '동고동락/NNG', '하/XSV', '면서/EC', '같이/JKB', '살/NNP', '분/NNB', '을/JKO', '찾/VV', '아요/EC', '사진/NNG', '은/JX', '서로/NNP', '가/JKS', '서산/NNP', '이/NNG', '되/XSV', '고/EC', '공개/NNG', '하/XSV', '게/EC', '습니다/EF', './SF', '가지/NNB', '것/NNB', '도/JX', '없/VA', '고/EC', '얼굴/NNP', '도/JX', '미/NNP', '남/NNP', '도/JX', '아니/VCN', '다/EF', './SF', '그냥/MAG', '평범/XR', '하/XSA', 'ㄴ/ETM', '사람/NNG', '이/VCP', 'ㅂ니/EP', '자/EC', '^/SW', '-/SS', '^/SW', '부디/MAG', '좋/VA', '은/ETM', '분/NNB', '이/VCP', '다가/EC', '와/JC', '조/NNP', '서면/NNG', '하/XSV', 'ㅂ니다/EF', './SF']
# ['아무것/NNG', '도/JX', '하/VV', '지/EC', '않/VX', '으면/EC', '아무/MM', '일/NNB', '도/JX', '일어나/VV', '지/EC', '않/VX', '죠/EF', './SF', '이성/NNG', '과/JC', '만남/NNG', '이/JKS', '힘들/VA', '어/EC', '지/VX', '는/ETM', '나/NP', '이대/NNP', '가/JKS', '되/VV', '었/EP', '어요/EC', '따지/VV', '지/EC', '않/VX', '고요/EF', './SF', '돌/VV', '싱/NNP', '이/VCP', '시/EP', 'ㄴ/ETM', '분/NNB', '들/XSN', '도/JX', '상관/NNG', '없/VA', '어요/EC', '여기/NP', '서/JKB', '좋/VA', '은/ETM', '분/NNB', '과/JKB', '함께/MAG', '하/XSA', 'ㄹ/ETM', '수/NNB', '있/VX', '다면/EC']
# ['/NA']
# ['/NA']
# ['"/SS', '아름답/VA', 'ㄴ/ETM', '이/MM', '세상/NNG', '소풍/NNG', '/NA', '끝내/VV', '는/ETM', '날/NNG', '', '/SP', '가/VV', '아서/EC', '아름답/VA', '었/EP', '다고/EC', '말/NNG', '하/XSV', '리라/EC', '~/SO', '~/SO', '~/SO', '*/SW', '어느/MM', '시인/NNG', '의/JKG', '/NA', '글/NNG', '처럼/JKB', '아름답/VA', 'ㄴ/ETM', '소풍/NNG', '을/JKO', '/NA', '함께/MAG', '하/VV', 'ㄹ/ETM', '/NA', '마음/NNG', '따뜻/XR', '하/XSA', 'ㄴ/ETM', '분/NNB', '/NA', '계시/VX', 'ㄴ가요/EF', '?/SF', '저/NP', '는/JX', '/NA', '초/NNB', '중/NNB', '학생/NNG', '들/XSN', '을/JKO', '/NA', '지도/NNG', '(/SS', '사교육/NNG', ')/SS', '하/XSV', '며/EC', '/NA', '보람/NNG', '과/JC', '/NA', '행복/NNG', '을/JKO', '느끼/VV', '는/ETM', '생활/NNG', '을/JKO', '/NA', '하/VV', '고/EC', '있/VX', '어요/EF', './SF', '항상/MAG', '긍정/NNG', '적/XSN', '으로/JKB', '/NA', '생각/NNG', '하/XSV', '고/EC', '/NA', '차분/XR', '하/XSA', '며/EC', '/NA', '밝/VA', '게/EC', '/NA', '잘/MAG', '/NA', '웃/VV', '는답니다/EF', './SF', '결혼/NNG', '보다/JKB', '는/JX', '친구/NNP', '같/VA', '은/ETM', '애인/NNG', '/NA', '원하/VV', '구요/EF', './SF', '전화/NNG', '보다/JKB', '는/JX', '/NA', '문자/NNG', '로/JKB', '/NA', '소소/XR', '하/XSA', 'ㄴ/ETM', '/NA', '생각/NNG', '과/JC', '/NA', '따뜻/XR', '하/XSA', 'ㄴ/ETM', '/NA', '마음/NNG', '주/VX', '고/EC', '받/VV', '을/ETM', '/NA', '수/NNB', '있/VV', '는/ETM', '분/NNB', '/NA', '원하/VV', '아요/EF', './SF', '/NA', '연하/VA', '는/ETM', '사절/NNG', '~/SO']
# ['안녕하십니까~~･ 평생 서로에게 도움되고서로에게 따뜻함과 의지가 될수있는 만남이 되었으면 좋겠습니다. /NA']
# ['몸과마음이온화하며착해요서로거짓없고잇는그대로친구처럼연인갇이사귀어보실분희망해요문자는못하니메세지남겨놓으면연락드리겟으요죄송해요/NA']
# ['여자/NNG', '에게/JKB', '상처/NNG', '를/JKO', '받/VV', '고/EC', '믿/VV', '고/EC', '결혼/NNG', '을/JKO', '하/VV', '았/EP', '는데/EC', '사기/NNG', '를/JKO', '당하/VV', '아서/EC', '이혼/NNG', '을/JKO', '결심/NNG', '하/XSV', '게/EC', '되/VX', '었/EP', '습니다/EF', './SF', '가정/NNG', '의/JKG', '무/XPN', '관심/NNG', '적/XSN', '이/VCP', 'ㄴ/ETM', '여자/NNG', '는/JX', '딱/MAG', '질색/NNG', '이/VCP', 'ㅂ니다/EF', './SF']
# ['안녕하세요/IC', '반갑/VA', '습니다/EC', '서로/MAG', '인연/NNG', '으로/JKB', '만나/VV', '아서/EC', '손/NNG', '꼭/MAG', '잡/VV', '고/EC', '남/VV', '은/ETM', '인생/NNG', '즐기/VV', '며/EC', '행복/NNG', '하/XSV', '게/EC', '아끼/VV', '어/EC', '주/VX', '며/EC', '살아가/VV', '고/EC', '싶/VX', '습니다/EF', './SF']
# ['제/MM', '소개/NNG', '를/JKO', '글/NNG', '로써/JKB', '장황/XR', '하/XSA', '게/EC', '작성/NNG', '하/XSV', '기/ETN', '보다/JKB', '는/JX', '단도직입/NNG', '적/XSN', '으로/JKB', '연락/NNG', '하/XSV', '고/EC', '만나/VV', '아서/EC', '알/VV', '아/EC', '가/VX', '고/EC', '싶/VX', '어요/EC', '그/NP', '게/JKB', '더/MAG', '의미/NNG', '있/VV', '다고/EC', '생각/NNG', '되/XSV', 'ㅂ니다/EC', '느낌/NNG', '적/XSN', '이/VCP', 'ㄴ/ETM', '느낌/NNG', '?/SF']

# %%
t1 = texts[1]
t1
# Out:
# '안녕하세요/IC, 회사/NNG, 다니/VV, 며/EC, 추/NNG, 말/NNG, 에/JKB, 는/JX, 캠핑/NNG, 다니/VV, 고/EC, 있/VV, 는/ETM, 평범/XR, 하/XSA, ㄴ/ETM, 직장인/NNG, 이/VCP, 에요/EC, 처음/NNG, 에/JKB, 는/JX, 낯설/VA, 고/EC, 잘/MAG, 모르/VV, 지만/EC, 서로/NNG, 에/JKB, 대하/VV, 아/EC, 알/VV, 아/EC, 가/VX, 면서/EC, 진지/XR, 하/XSA, ㄴ/ETM, 관계/NNG, 로/JKB, 발전/NNG, 하/XSV, 았/EP, 으면/EC, 하/VX, 아요/EC'

# %%
def get_lst(t1):
    final_lst = []
    t_lst = t1.split(',')
    for t in t_lst:
        t= t.strip()
        final_lst.append(t)

    return final_lst

# %%
abc = get_lst(t1)
abc
# Out:
# ['안녕하세요/IC',
#  '회사/NNG',
#  '다니/VV',
#  '며/EC',
#  '추/NNG',
#  '말/NNG',
#  '에/JKB',
#  '는/JX',
#  '캠핑/NNG',
#  '다니/VV',
#  '고/EC',
#  '있/VV',
#  '는/ETM',
#  '평범/XR',
#  '하/XSA',
#  'ㄴ/ETM',
#  '직장인/NNG',
#  '이/VCP',
#  '에요/EC',
#  '처음/NNG',
#  '에/JKB',
#  '는/JX',
#  '낯설/VA',
#  '고/EC',
#  '잘/MAG',
#  '모르/VV',
#  '지만/EC',
#  '서로/NNG',
#  '에/JKB',
#  '대하/VV',
#  '아/EC',
#  '알/VV',
#  '아/EC',
#  '가/VX',
#  '면서/EC',
#  '진지/XR',
#  '하/XSA',
#  'ㄴ/ETM',
#  '관계/NNG',
#  '로/JKB',
#  '발전/NNG',
#  '하/XSV',
#  '았/EP',
#  '으면/EC',
#  '하/VX',
#  '아요/EC']

# %%
for text in ggg:
    final_lst = get_lst(text)
    print(final_lst)
# Out:
# ['반갑습니다.  여행과 운동 그리고 음악을 좋아하는 남자입니다. 취미를 함께하며 평생 인생의 동반자로 즐겁게 살고싶습니다.  좋은 인연이 되길!']
# ['안녕하세요 회사다니며 추말엔 캠핑 다니고 있는 평범한 직장인이에요 처음엔 낯설고 잘 모르지만 서로에 대해 알아가면서 진지한 관계로 발전했으면해요']
# ['화려한 돌씽입니다. 맘 맞는분 만나서 남은 반생 같이하고 싶습니다.  여행가는것 좋아합니다']
# ['반갑습니다. 새로운 인연 기다립니다. 같은 생각으로 같은 길을 갔으면 합니다.']
# ['여보야는 2015년에 런칭했으며 2022년도에는 4만쌍의 성혼을 이루도록 더 많은 홍보를 하겠습니다. 많은 관심부탁드립니다.']
# ['좋은사람 좋은인연 기다립니다.그럼 오늘하루도..즐겁고 행복한 하루 되세요~']
# ['진지한 만남을 원하며 천천히 한사람을 알아가는 걸 좋아합니다']
# ['세상의 흔한 만남보다. 세상에서 제일 아름다운 사랑을 하고 싶습니다. 조건따지는 분은 패스']
# ['']
# ['평범한 직장여성입니다. 워킹맘으로 앞만 보고 살아왔는데 이제는진정 서로 아끼는 평생의 반려자를 만나 노후는 행복하게 살고 싶습니다. 연하는 싫습니다']
# ['착하게 만나보고 싶어서 왔어요 착한분 연락되면 좋겠네요 프로필 보시고 쪽지주세요~ 파주운정문산쪽분 계시면 좋아요']
# ['늦은 나이까지 인연을 못 만나고 있네요^^;; 서로에게 힘이 될 수 있는 좋은 사람을 만나고 싶습니당~ 진지한 만남 원해요']
# ['매사 긍정적이고 배려심많고 심서미곱고 착한여자입니다']
# ['편하게 만날수 있는 인연을 찾고 싶어서 가입했어요 진지하게 만날수 있는 사람이면 좋겠어요']
# ['69~71년생 친구 같은 분', '별거중이고 이혼 소송중이신 분은 떳떳히 밝히시고 같은 처지 정리안되신 여자를 만나세요. 연애', '동거 즐기는 삶보다는 함께 늙어가며 서로를 책임지고 무덤까지 함께 갈수 있는 짝을 만나고 싶습니다.. 커리어우먼 보다는 한남자의 사랑 받는 아내로 살고 싶습니다.말많고 목소리 큰남자', '돌직구', '매사에 트집', '무능함과 열등감', '숨기는게 많은 사람', '멘탈장애가 있으신 분과는 인연 안되길 바랍니다 가식적인 친절함 아니고 성품이 유하고', '조용하신분', '순수하게 사랑 할수 있는 사람 만나고 싶어요']
# ['오늘 가입했습니다 평생친구 찾습니다 행복하세요 삶을 긍정하고 즐겁게 삽시다 배우는걸 좋아해요 지금 영어 피아노 골프 배워요ㅎ']
# ['미국 거주 컴퓨터 공학 박사이며 현재 스타텁 파운더입니다. 부모님 뵈러 한국 들어와 있습니다!']
# ['반갑습니다^^ 좋은 인연찾아봅니다. 마음이 예쁘신분~ 어디있을까요']
# ['공무원 직업 확실한 분사업하는분 싫어요 키 크고 지적이고 통통한스타일입니다 귀여운스탈 아닙니다 거짓말 하는거제일싫어해요생각없이문자보내는 분 서로에너지 낭비 하지맙시다 모든요리 다잘하고소비성향합리적입니다 과소비 충동구매안합니다 성격 상냥하고좋다생각합니다']
# ['']
# ['건강한 마음 과 건전한 생각을 가지고 살아가는사람입니다 주님의 나라를 섬기며 즐겁고 기쁘게 살아가는 인 입니다']
# ['우리가 인생을 살아가면서 운명적인 사람을 만날 수 있는 기회가 얼마나 될까요? 배우자가 운명적인 만남이 아닐지라도 어느정도 맞춰가며 살 수 있는 사람이면 좋겠습니다. 만나는 사람이 집착하지 않고', '배려심 깊은 사람이었으면 좋겠습니다. 저는 먼가를 배우는 걸 좋아하고 하루하루를 알차게 보내려고 노력하는 사람입니다. 지금 꽤 공들이고 있는 취미 활동은 음악 영상을 만드는 유튜버입니다. 항상 시간에 쫓기다보니', '귀찮아서 술.담배를 모두 끊었습니다. 그런 시간은 좋은 취미 활동으로 대신 채우고 싶어요. 그냥 마음이 통하는 그런 분 만나고 싶ㅇ']
# ['안녕하세요. 저는 건강한 마음의 50대 평범한 남자입니다. 서로의 일상적인 안부를 전하고봄 가을에는 서로의 계절감성을 나누고맛있는걸 먹게되면 두손 꼭 부여잡고 같이 오고싶은 상대를 만나면 좋겠습니다. 상대에게 따뜻한 마음이 되어주고 싶네요.저도 따뜻한 마음 느껴보고싶구요^^']
# ['초혼입니다.. 힘들다고 생각하면 더 힘들고 외롭다고 생각하면 더 외롭게 느껴집니다 하나보단 둘 서로 의지하고 남은 인생 즐겁게 보네실분을 기다립니다..다른건 몰라도 성격하난 쿨합니다...제가 초혼이라 초혼만고집하지는 안습니다..^인연^ 만나고 싶습니다Ps 남은 인생 호수 처럼 잔잔하게 살고 싶습니다....']
# ['좋은사람이 되기위해 노력하는 한사람입니다 상대방도 그랬으면 좋겠네요']
# ['혼자된지 좀 됬습니다 바쁘게 살다보니 이런것도 모르고 살다가 이제 좋은분 만나서 조금씩 알아가며여유롭게살고싶네요']
# ['안녕하세요.춘천에서 제조업하고 있는 30살 남자입니다.']
# ['안녕하세요 ~ 머라적어야할지. . .일단 결혼은 하고 싶습니다 좋아요 찜 버튼이 있는부분인지 모르지만 눌러주세요~ ^^']
# ['안녕하세요모든 회원님들 반갑습니다저는 꼭 재혼이아니라도 진정한 인생 친구라도 인연맸고 십네요 저와같은 생각하신분 손들어 주세요제가 찻아 갈게요']
# ['']
# ['안녕하세요 ^^ 좋은 만남 기대합니다 말길게 해봤자 다거기서 거긴거 같구요~~ 만나면서 알아가요~^^']
# ['대화가통하는 친구를원해요서로 위로해주고 마음이따뜻한사람이었으면 좋겠어요']
# ['저는 48살 노총각입니다 저와 마음맞는 상대를 만나 평생을 함께 행복하게 살고 싶습니다']
# ['일때문에 여기저기 다니다보니 인연을 만나기가 힘드내요  혼자 영화보고 밥먹고 쓸쓸하니 좋은 인연 만나서  행복했으면 좋겠습니다 관심 많이가져 주세요ㅎ  경남양산집이나 경북군위집에 주말마다 내려가고 지금일하는곳은 경북울진입니다']
# ['평범하고 평범한분을 뵙고싶고 열심히 살고있는 청년입니다.']
# ['음주 못하고요 담배안하고요 종교없고요 운동좋아하고요 정이 많다요 외롭지 않게 늘곁에서 함께 할게요. 가끔 야구장(잠실', '고척', '수원', '문학) 데이트 가실분 환영입니다^^']
# ['안녕하세요. 잘지내요 근데 이앱 괜찮은건가요? 반신반의 하네 믿을수 있는건가']
# ['좋은사람 만고 싶어 가입하게 되었습니다   결혼할 나이가 된 것 같아 좋은인연이 될분을 만나고 싶네요']
# ['항상 밝고 즐거운 마인드로 삶을 살고 있는 한 남자입니다']
# ['열심히앞만보고달려오다보니 벌써이렇게되었네요 좋은분만나서 아름다운여행같은삶을살고싶어요']
# ['앞만보고달려시간이이렇게가는지도모르고지내서요.늦으지만좋은분을만나행복하게살고싶습니다.그래도남대로생활하고취미활동을하고지낸거같습니다. 늦어지만평생동고동락하면서같이살분을찾아요 사진은서로가서산이되면공개하게습니다. 가지것도없고얼굴도미남도아니다.그냥평범한사람입니자^-^ 부디좋은분이다가와조서면합니다.']
# ['아무것도 하지않으면 아무일도 일어나지않죠. 이성과 만남이 힘들어지는 나이대가 되었어요 따지지않고요. 돌싱이신 분들도 상관 없어요여기서 좋은분과 함께할수있다면']
# ['']
# ['']
# ['"아름다운 이 세상소풍  끝내는 날', '가서 아름다웠다고 말하리라~~~* 어느 시인의  글처럼아름다운 소풍을  함께 할  마음 따뜻한 분  계신가요? 저는  초 중 학생들을  지도(사교육)하며  보람과  행복을느끼는생활을  하고 있어요.항상 긍정적으로  생각하고  차분하며  밝게  잘  웃는답니다. 결혼보다는친구같은 애인  원하구요. 전화보다는  문자로  소소한  생각과  따뜻한  마음 주고 받을  수 있는 분  원해요.  연하는 사절~']
# ['안녕하십니까~~･ 평생 서로에게 도움되고서로에게 따뜻함과 의지가 될수있는 만남이 되었으면 좋겠습니다.']
# ['몸과마음이온화하며착해요서로거짓없고잇는그대로친구처럼연인갇이사귀어보실분희망해요문자는못하니메세지남겨놓으면연락드리겟으요죄송해요']
# ['여자에게 상처를받고 믿고 결혼을 했는데 사기를 당해서 이혼을결심하게되었습니다.가정의 무관심적인 여자는딱 질색입니다.']
# ['안녕하세요 반갑습니다 서로 인연으로 만나서 손 꼭잡고 남은인생 즐기며 행복하게 아껴주며 살아가고 싶습니다.']
# ['제 소개를 글로써 장황하게 작성하기보단 단도직입적으로 연락하고 만나서 알아가고 싶어요 그게 더 의미 있다고 생각됩니다 느낌적인 느낌?']

# %%
t2 = texts[2]
t2
# Out:
# '화려/XR, 하/XSA, ㄴ/ETM, 돌/VV, 씽/NNP, 이/VCP, ㅂ니다/EF, ./SF, 맘/NNG, 맞/VV, 는/ETM, 분/NNB, 만나/VV, 아서/EC, 남/VV, 은/ETM, 반생/NNG, 같이/MAG, 하/XSV, 고/EC, 싶/VX, 습니다/EF, ./SF, /NA, 여행가/NNG, 이/VCP, 는/ETM, 것/NNB, 좋아하/VV, ㅂ니다/EC'

# %%
get_lst()

# %%
g1 = ggg[1]

# %%
f_lst = get_lst(g1)
f_lst
# Out:
# ['안녕하세요 회사다니며 추말엔 캠핑 다니고 있는 평범한 직장인이에요 처음엔 낯설고 잘 모르지만 서로에 대해 알아가면서 진지한 관계로 발전했으면해요']

# %%
g1
# Out:
# '안녕하세요 회사다니며 추말엔 캠핑 다니고 있는 평범한 직장인이에요 처음엔 낯설고 잘 모르지만 서로에 대해 알아가면서 진지한 관계로 발전했으면해요'

# %%
komoran = Komoran()
def komoran_tokenize(sent):
    words = komoran.pos(sent, join=True)
    words = [w for w in words if ('/NNG' in w and (len(w)>=2 or len(w)<4))]
    return words

# %%
data['textrank'] = data['mate_conts'].apply(komoran_tokenize)
data.head(3)
# Out:
#     mem_no mem_sex                                         mate_conts  \
# 0        5       m  반갑습니다.  여행과 운동 그리고 음악을 좋아하는 남자입니다. 취미를 함께하며 평생...
# 1  1407510       m  안녕하세요 회사다니며 추말엔 캠핑 다니고 있는 평범한 직장인이에요 처음엔 낯설고 잘...
# 2        2       m  화려한 돌씽입니다. 맘 맞는분 만나서 남은 반생 같이하고 싶습니다.  여행가는것 좋...
#
#                                              komoran  \
# 0  반갑/VA, 습니다/EF, ./SF, /NA, 여행/NNG, 과/JC, 운동/NNG...
# 1  안녕하세요/IC, 회사/NNG, 다니/VV, 며/EC, 추/NNG, 말/NNG, 에...
# 2  화려/XR, 하/XSA, ㄴ/ETM, 돌/VV, 씽/NNP, 이/VCP, ㅂ니다/E...
#
#                                             textrank
# 0  [여행/NNG, 운동/NNG, 음악/NNG, 남자/NNG, 취미/NNG, 평생/NN...
# 1  [회사/NNG, 추/NNG, 말/NNG, 직장인/NNG, 처음/NNG, 서로/NNG...
# 2                            [맘/NNG, 반생/NNG, 여행/NNG]

# %%
data['textrank']
# Out:
# 0     [여행/NNG, 운동/NNG, 음악/NNG, 남자/NNG, 취미/NNG, 평생/NN...
# 1     [회사/NNG, 추/NNG, 말/NNG, 직장인/NNG, 처음/NNG, 서로/NNG...
# 2                               [맘/NNG, 반생/NNG, 여행/NNG]
# 3                                       [생각/NNG, 길/NNG]
# 4        [여보/NNG, 런/NNG, 쌍/NNG, 홍보/NNG, 관심/NNG, 부탁/NNG]
# 5                      [오늘/NNG, 하루/NNG, 행복/NNG, 하루/NNG]
# 6                                      [만남/NNG, 사람/NNG]
# 7      [세상/NNG, 만남/NNG, 세상/NNG, 제일/NNG, 사랑/NNG, 조건/NNG]
# 8                                                    []
# 9     [직장/NNG, 여성/NNG, 앞/NNG, 이제/NNG, 평생/NNG, 반려자/NN...
# 10                                    [연락/NNG, 프로필/NNG]
# 11              [나이/NNG, 인연/NNG, 서로/NNG, 힘/NNG, 사람/NNG]
# 12                      [매사/NNG, 긍정/NNG, 배려/NNG, 심/NNG]
# 13                             [인연/NNG, 가입/NNG, 사람/NNG]
# 14    [친구/NNG, 처지/NNG, 정리/NNG, 안/NNG, 여자/NNG, 삶/NNG,...
# 15      [오늘/NNG, 가입/NNG, 평생/NNG, 행복/NNG, 삶/NNG, 긍정/NNG]
# 16                     [거주/NNG, 박사/NNG, 스타/NNG, 부모/NNG]
# 17                                     [인연/NNG, 마음/NNG]
# 18    [공무원/NNG, 직업/NNG, 사업/NNG, 키/NNG, 지적/NNG, 일/NNG...
# 19                                                   []
# 20    [건강/NNG, 마음/NNG, 과/NNG, 생각/NNG, 주님/NNG, 나라/NNG...
# 21    [인생/NNG, 운명/NNG, 사람/NNG, 기회/NNG, 운명/NNG, 만남/NN...
# 22    [건강/NNG, 마음/NNG, 남자/NNG, 서로/NNG, 일상/NNG, 안부/NN...
# 23    [생각/NNG, 생각/NNG, 의지/NNG, 인생/NNG, 보/NNG, 실/NNG,...
# 24                            [노력/NNG, 사람/NNG, 상대방/NNG]
# 25                             [혼자/NNG, 조금/NNG, 여유/NNG]
# 26                                    [제조업/NNG, 남자/NNG]
# 27                              [결혼/NNG, 찜/NNG, 부분/NNG]
# 28     [회원/NNG, 재혼/NNG, 인생/NNG, 친구/NNG, 인연/NNG, 주세/NNG]
# 29                                                   []
# 30                               [기대/NNG, 말/NNG, 다/NNG]
# 31              [대화/NNG, 친구/NNG, 원/NNG, 위로/NNG, 마음/NNG]
# 32            [노총각/NNG, 마음/NNG, 상대/NNG, 평생/NNG, 행복/NNG]
# 33    [여기저기/NNG, 인연/NNG, 힘/NNG, 혼자/NNG, 영화/NNG, 밥/NN...
# 34                                             [청년/NNG]
# 35    [담배/NNG, 안/NNG, 종교/NNG, 운동/NNG, 곁/NNG, 가실/NNG,...
# 36                                           [반신반의/NNG]
# 37                             [가입/NNG, 결혼/NNG, 나이/NNG]
# 38                                      [삶/NNG, 남자/NNG]
# 39                                       [앞/NNG, 삶/NNG]
# 40    [평생/NNG, 동고동락/NNG, 이/NNG, 공개/NNG, 얼굴/NNG, 입/NN...
# 41                    [아무것/NNG, 이성/NNG, 만남/NNG, 상관/NNG]
# 42                                                   []
# 43                                                   []
# 44    [세상/NNG, 날/NNG, 말/NNG, 시인/NNG, 글/NNG, 소풍/NNG, ...
# 45             [평생/NNG, 서로/NNG, 도움/NNG, 의지/NNG, 만남/NNG]
# 46                                                   []
# 47    [여자/NNG, 상처/NNG, 결혼/NNG, 사기/NNG, 이혼/NNG, 을/NNG...
# 48                              [인연/NNG, 손/NNG, 행복/NNG]
# 49    [소개/NNG, 글/NNG, 작성/NNG, 단도직입/NNG, 연락/NNG, 의미/N...
# Name: textrank, dtype: object

# %%
t1 = data['textrank'].iloc[0]
t1
# Out:
# ['반갑습니다/NNP',
#  '여행/NNG',
#  '운동/NNG',
#  '음악/NNG',
#  '좋아하/VV',
#  '남자/NNG',
#  '취미/NNG',
#  '평생/NNG',
#  '인생/NNG',
#  '동반자/NNP',
#  '즐겁/VA',
#  '살/VV',
#  '좋/VA',
#  '인연/NNG',
#  '되/VV']

# %%
keyword_extractor = KeywordSummarizer(
    tokenize = komoran_tokenize,
    window = -1,
    verbose = False
)

# %%
keywords = keyword_extractor.summarize(t1, topk=30)
for word, rank in keywords:
    print('{} ({:.3})'.format(word, rank))
# Out:
# VV/NNP (0.15)

# %%
counter = Counter(t1)
print(counter)
# Out:
# Counter({'반갑습니다/NNP': 1, '여행/NNG': 1, '운동/NNG': 1, '음악/NNG': 1, '좋아하/VV': 1, '남자/NNG': 1, '취미/NNG': 1, '평생/NNG': 1, '인생/NNG': 1, '동반자/NNP': 1, '즐겁/VA': 1, '살/VV': 1, '좋/VA': 1, '인연/NNG': 1, '되/VV': 1})

# %%
counter = {w:c for w,c in counter.items() if c >=1}
counter
# Out:
# {'반갑습니다/NNP': 1,
#  '여행/NNG': 1,
#  '운동/NNG': 1,
#  '음악/NNG': 1,
#  '좋아하/VV': 1,
#  '남자/NNG': 1,
#  '취미/NNG': 1,
#  '평생/NNG': 1,
#  '인생/NNG': 1,
#  '동반자/NNP': 1,
#  '즐겁/VA': 1,
#  '살/VV': 1,
#  '좋/VA': 1,
#  '인연/NNG': 1,
#  '되/VV': 1}
